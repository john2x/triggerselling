# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
html = requests.get("https://www.youtube.com/user/bartkwan/channels").text
bs = BeautifulSoup(html)
channels = []
for li in bs.find_all("li",{"class":"channels-content-item"}):
    subs = li.find("span",{"class":"yt-subscription-button-subscriber-count-unbranded-horizontal"})["aria-label"]
    subs = int(subs.replace(",","").split()[0])
    name = li.find("h3").text.split(" - ")[0]
    link = li.find("a")["href"]
    logo = li.find("img")["src"]
    cols = ["subs","name","link","logo"]
    vals = [subs,name,link,logo]
    channels.append(dict(zip(cols, vals)))

# %%
html = requests.get("https://instagram.com/p/2Mf1UgTVxk/").text
bs = BeautifulSoup(html)
lol = bs.find_all("script")[-4].text[21:]
lol = json.loads(lol[:-1])
#user = lol["entry_data"]["ProfilePage"][0]["user"]
user = lol["entry_data"]["PostPage"][0]["media"]["owner"]

# %%
r = requests.get("https://api.soundcloud.com/users/113250487/followings?client_id=02gUJC0hH2ct1EGOcYXQIzRFU91c72Ea&limit=250")

# %%
len(r.json())
# Out:
# 174

# %%
import metadata_parser

# %%
# json scrape / scrape
html = requests.get("https://soundcloud.com/edm/blackmail-by-dallask-henry").text
bs = BeautifulSoup(html)
md = page = metadata_parser.MetadataParser(html=r.text)
song_info = json.loads(bs.find_all("script")[-1].text.split("c,o,i=")[-1].split(",u=Date")[0])

# %%
# html scrape
url = "https://soundcloud.com/edm/blackmail-by-dallask-henry"
html = requests.get("http://localhost:8950/render.html?url=").text

# %%
url = "https://soundcloud.com/edm/blackmail-by-dallask-henry"

# %%
# endpoints
# - pagination
# -

# %%
import pandas as pd
import rethinkdb as r

# %%
conn = r.connect(db="socialiq")

# %%
yt = list(r.table("youtube_profiles").run(conn))

# %%
pd.DataFrame(yt).to_hdf("/Users/robin/Projects/tmp/youtube.h5",index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-abecfbd3a6b7> in <module>()
# ----> 1 pd.DataFrame(yt).to_hdf("/Users/robin/Projects/tmp/youtube.h5",index=False)
#
# TypeError: to_hdf() takes exactly 3 arguments (2 given)

# %%
[] == []
# Out:
# True

# %%
import urlparse
import urllib

# %%
u = "https://www.google.ca/search?biw=1272&bih=636&noj=1&q=decode+url+arguments+to+dictionary+python&oq=decode+url+arguments+to+dictionary+python&gs_l=serp.3...2085.2818.0.3137.7.7.0.0.0.0.168.648.4j2.6.0....0...1c.1.64.serp..4.3.312.idhTRLj0PYU"

# %%
dict(urlparse.parse_qsl(urlparse.urlparse(u).query))
# Out:
# {'bih': '636',
#  'biw': '1272',
#  'gs_l': 'serp.3...2085.2818.0.3137.7.7.0.0.0.0.168.648.4j2.6.0....0...1c.1.64.serp..4.3.312.idhTRLj0PYU',
#  'noj': '1',
#  'oq': 'decode url arguments to dictionary python',
#  'q': 'decode url arguments to dictionary python'}

# %%
pd.read_hdf("/Users/robin/Projects/tmp/youtube.h5")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-118-b4ffdd153eef> in <module>()
# ----> 1 pd.read_hdf("/Users/robin/Projects/tmp/youtube.h5")
#
# /Users/robin/anaconda/lib/python2.7/site-packages/pandas/io/pytables.pyc in read_hdf(path_or_buf, key, **kwargs)
#     314
#     315         if not exists:
# --> 316             raise IOError('File %s does not exist' % path_or_buf)
#     317
#     318         # can't auto open/close if we are using an iterator
#
# IOError: File /Users/robin/Projects/tmp/youtube.h5 does not exist

# %%
    data = r.table("triggers").filter(lambda trigger: trigger.has_fields("domain"))
    #data = data.order_by("created_at")
    data = data.order_by(r.desc("timestamp"))
    data = data.without(["company_domain_research_completed","emailhunter_search_completed"])
    data = data.eq_join("profile", r.table("prospect_profiles"))
    data = data.slice(page*50, (page+1)*50).limit(50).zip()

# %%
u = "http://api.emailhunter.co/v1/search?domain={0}&api_key=493b454750ba86fd4bd6c2114238ef43696fce14"

# %%
requests.get(u.format("stripe.com")).json()
# Out:
# {u'domain': u'stripe.com',
#  u'emails': [{u'sources': [{u'domain': u'menuzo-svanou.c9.io',
#      u'extracted_on': u'2015-10-26',
#      u'uri': u'http://menuzo-svanou.c9.io/products/34'},
#     {u'domain': u'about-payments.com',
#      u'extracted_on': u'2015-10-26',
#      u'uri': u'http://about-payments.com/knowledge-base/provider/stripe'},
#     {u'domain': u'reddit.com',
#      u'extracted_on': u'2015-10-25',
#      u'uri': u'http://reddit.com/user/powerlanguage'},
#     {u'domain': u'pythonanywhere.com',
#      u'extracted_on': u'2015-10-22',
#      u'uri': u'http://pythonanywhere.com/forums/topic/2694/rss'},
#     {u'domain': u'fs21.formsite.com',
#      u'extracted_on': u'2015-10-21',
#      u'uri': u'http://fs21.formsite.com/documentation/payments/stripe.html'},
#     {u'domain': u'fancy.com',
#      u'extracted_on': u'2015-10-21',
#      u'uri': u'http://fancy.com/resources/anywhere'},
#     {u'domain': u'formsite.com',
#      u'extracted_on': u'2015-10-20',
#      u'uri': u'http://formsite.com/documentation/payments/stripe.html'},
#     {u'domain': u'zkorean.com',
#      u'extracted_on': u'2015-10-20',
#      u'uri': u'http://zkorean.com/account/register'},
#     {u'domain': u'fs6.formsite.com',
#      u'extracted_on': u'2015-10-16',
#      u'uri': u'http://fs6.formsite.com/documentation/payments/stripe.html'},
#     {u'domain': u'fs11.formsite.com',
#      u'extracted_on': u'2015-10-15',
#      u'uri': u'http://fs11.formsite.com/documentation/payments/stripe.html'},
#     {u'domain': u'causes.com',
#      u'extracted_on': u'2015-03-01',
#      u'uri': u'http://causes.com/help'},
#     {u'domain': u'mail.haskell.org',
#      u'extracted_on': u'2015-03-01',
#      u'uri': u'http://mail.haskell.org/pipermail/xmonad/2009-June/008055.html'},
#     {u'domain': u'programmableweb.com',
#      u'extracted_on': u'2015-01-30',
#      u'uri': u'http://programmableweb.com/rss'},
#     {u'domain': u'programmableweb.com',
#      u'extracted_on': u'2015-04-27',
#      u'uri': u'http://programmableweb.com/api/stripe'},
#     {u'domain': u'wcd.coe.int',
#      u'extracted_on': u'2015-03-01',
#      u'uri': u'http://wcd.coe.int/ViewDoc.jsp'},
#     {u'domain': u'seatgeek.com',
#      u'extracted_on': u'2015-03-02',
#      u'uri': u'http://seatgeek.com/go-deep-tickets'},
#     {u'domain': u'delawareyouthcenter.org',
#      u'extracted_on': u'2015-04-28',
#      u'uri': u'http://delawareyouthcenter.org'},
#     {u'domain': u'getdispatch.com',
#      u'extracted_on': u'2015-04-28',
#      u'uri': u'http://getdispatch.com'},
#     {u'domain': u'rubydoc.info',
#      u'extracted_on': u'2015-01-30',
#      u'uri': u'http://rubydoc.info/github/stripe/stripe-ruby/master/stripe'},
#     {u'domain': u'getclearstream.com',
#      u'extracted_on': u'2015-01-31',
#      u'uri': u'http://getclearstream.com/moving-to-stripe-for-credit-card-payments'},
#     {u'domain': u'astonkinetics.com',
#      u'extracted_on': u'2015-01-31',
#      u'uri': u'http://astonkinetics.com'},
#     {u'domain': u'northernfarmhousepasta.com',
#      u'extracted_on': u'2015-01-26',
#      u'uri': u'http://northernfarmhousepasta.com'},
#     {u'domain': u'delawareyouthcenter.org',
#      u'extracted_on': u'2015-02-01',
#      u'uri': u'http://delawareyouthcenter.org/the-river-run-2013'},
#     {u'domain': u'bobbywarner.com',
#      u'extracted_on': u'2015-04-27',
#      u'uri': u'http://bobbywarner.com/2011/12/29/using-stripe-with-grails'},
#     {u'domain': u'holmesharborcellars.com',
#      u'extracted_on': u'2015-04-27',
#      u'uri': u'http://holmesharborcellars.com'},
#     {u'domain': u'amberonrails.com',
#      u'extracted_on': u'2015-01-28',
#      u'uri': u'http://amberonrails.com/building-stripes-api'},
#     {u'domain': u'delawareyouthcenter.org',
#      u'extracted_on': u'2015-05-05',
#      u'uri': u'http://delawareyouthcenter.org/events'},
#     {u'domain': u'siliconprairienews.com',
#      u'extracted_on': u'2015-05-03',
#      u'uri': u'http://siliconprairienews.com/2013/02/tools-of-the-trade-stripe-makes-accepting-credit-cards-online-easy'},
#     {u'domain': u'stackoverflow.com',
#      u'extracted_on': u'2015-05-07',
#      u'uri': u'http://stackoverflow.com/questions/5787776/a-worthy-developer-friendly-alternative-to-paypal'},
#     {u'domain': u'amberonrails.com',
#      u'extracted_on': u'2015-04-26',
#      u'uri': u'http://amberonrails.com'}],
#    u'type': u'generic',
#    u'value': u'support@stripe.com'},
#   {u'sources': [{u'domain': u'yqopejobi.opx.pl',
#      u'extracted_on': u'2015-10-29',
#      u'uri': u'http://yqopejobi.opx.pl/start-4-fun-net-videos.php'},
#     {u'domain': u'github.com',
#      u'extracted_on': u'2014-04-16',
#      u'uri': u'http://github.com/stripe/einhorn/blob/v0.3.1/einhorn.gemspec'},
#     {u'domain': u'github.com',
#      u'extracted_on': u'2014-04-16',
#      u'uri': u'http://github.com/eventmachine/eventmachine'},
#     {u'domain': u'hnhiring.com',
#      u'extracted_on': u'2014-04-16',
#      u'uri': u'http://hnhiring.com'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-17',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-20',
#      u'uri': u'http://stripe.com/blog/feed.rss'},
#     {u'domain': u'github.com',
#      u'extracted_on': u'2014-04-20',
#      u'uri': u'http://github.com/eventmachine/eventmachine/commits/master'},
#     {u'domain': u'radioshack.com',
#      u'extracted_on': u'2015-05-05',
#      u'uri': u'http://radioshack.com/cell-phones/apple-iphone'},
#     {u'domain': u'github.com',
#      u'extracted_on': u'2015-05-05',
#      u'uri': u'http://github.com/stripe/einhorn/blob/v0.4.8/einhorn.gemspec'},
#     {u'domain': u'kirksvilledailyexpress.com',
#      u'extracted_on': u'2015-05-05',
#      u'uri': u'http://kirksvilledailyexpress.com/article/20130113/NEWS/301139968/1006'},
#     {u'domain': u'ticketnetwork.com',
#      u'extracted_on': u'2015-05-05',
#      u'uri': u'http://ticketnetwork.com/tickets/sarah-brightman--in--toronto-on.aspx'},
#     {u'domain': u'wkyt.com',
#      u'extracted_on': u'2015-05-05',
#      u'uri': u'http://wkyt.com/yourtown/headlines/Chick-fil-A-Central-KY-hosts-Girls-Night-Out-May-2014-255763651.html'},
#     {u'domain': u'usef.org',
#      u'extracted_on': u'2015-03-05',
#      u'uri': u'http://usef.org/_IFrames/competitions/compSearches/classPoints.aspx'},
#     {u'domain': u'apps.who.int',
#      u'extracted_on': u'2015-03-04',
#      u'uri': u'http://apps.who.int/iris/browse'},
#     {u'domain': u'azcentral.com',
#      u'extracted_on': u'2015-03-04',
#      u'uri': u'http://azcentral.com/thingstodo/movies/search'},
#     {u'domain': u'fanatics.com',
#      u'extracted_on': u'2015-03-04',
#      u'uri': u'http://fanatics.com/NFL_Super_Bowl_Merchandise_Mens_Hats_Fitted/47_Brand_Seattle_Seahawks_Super_Bowl_XLVIII_Champions_Franchise_Fitted_Hat_-_College_Navy'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/stellar'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/ctf3-architecture'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/email-transparency'},
#     {u'domain': u'whitestuff.com',
#      u'extracted_on': u'2015-05-05',
#      u'uri': u'http://whitestuff.com/mens/trousers'},
#     {u'domain': u'github.com',
#      u'extracted_on': u'2015-07-03',
#      u'uri': u'http://github.com/stripe/einhorn/blob/v0.4.0/einhorn.gemspec'}],
#    u'type': u'personal',
#    u'value': u'gdb@stripe.com'},
#   {u'sources': [{u'domain': u'goodshuffle.com',
#      u'extracted_on': u'2015-10-13',
#      u'uri': u'http://goodshuffle.com/terms'},
#     {u'domain': u'suretomeet.com',
#      u'extracted_on': u'2015-10-04',
#      u'uri': u'http://suretomeet.com/exec/gt/tpl.h,content=291'},
#     {u'domain': u'prestashop.com',
#      u'extracted_on': u'2015-07-01',
#      u'uri': u'http://prestashop.com/fr/partenaires'},
#     {u'domain': u'github.com',
#      u'extracted_on': u'2014-04-18',
#      u'uri': u'http://github.com/stripe/einhorn'},
#     {u'domain': u'github.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://github.com/stripe/einhorn/blob/master/readme.md'},
#     {u'domain': u'github.com',
#      u'extracted_on': u'2015-05-05',
#      u'uri': u'http://github.com/stripe/einhorn/blob/v0.4.0/README.md.in'},
#     {u'domain': u'raw.githubusercontent.com',
#      u'extracted_on': u'2015-05-04',
#      u'uri': u'http://raw.githubusercontent.com/stripe/einhorn/master/README.md.in'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/contact/sales'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/meet-einhorn'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/contact'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/help/contact'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/10'},
#     {u'domain': u'github.com',
#      u'extracted_on': u'2014-04-16',
#      u'uri': u'http://github.com/stripe/einhorn/tree/c5a71cadb5e2687a5345570854d972d83cdd1b94'},
#     {u'domain': u'github.com',
#      u'extracted_on': u'2015-05-06',
#      u'uri': u'http://github.com/stripe/einhorn/blob/139fbf3929708ecb1f4792a33b837e396e597199/LICENSE'},
#     {u'domain': u'selectscience.net',
#      u'extracted_on': u'2015-05-06',
#      u'uri': u'http://selectscience.net/oligonucleotides/product-directory/services'},
#     {u'domain': u'secure.shareit.com',
#      u'extracted_on': u'2015-04-27',
#      u'uri': u'http://secure.shareit.com/shareit/checkout.html'},
#     {u'domain': u'wiki.openmoko.org',
#      u'extracted_on': u'2015-04-27',
#      u'uri': u'http://wiki.openmoko.org/wiki/Special:WhatLinksHere/A_handful_of_Constitute_Tips_For_You_to_ultimately_Pursue'}],
#    u'type': u'generic',
#    u'value': u'info@stripe.com'},
#   {u'sources': [{u'domain': u'ultracart.com',
#      u'extracted_on': u'2015-10-30',
#      u'uri': u'http://ultracart.com/resources/partners/supported-payment-gateways/usgateways/stripe/'},
#     {u'domain': u'tripleseat.com',
#      u'extracted_on': u'2015-10-25',
#      u'uri': u'http://tripleseat.com/blog/online-credit-cards-payments-with-tripleseat/'},
#     {u'domain': u'poundpay.com',
#      u'extracted_on': u'2015-10-01',
#      u'uri': u'http://poundpay.com/stripe/faq'},
#     {u'domain': u'socialseam.org',
#      u'extracted_on': u'2015-09-23',
#      u'uri': u'http://socialseam.org/about/stripe'},
#     {u'domain': u'balancedpayments.com',
#      u'extracted_on': u'2015-09-09',
#      u'uri': u'http://balancedpayments.com/stripe/faq'},
#     {u'domain': u'xero.com',
#      u'extracted_on': u'2015-07-28',
#      u'uri': u'http://xero.com/add-ons/35-stripe/'},
#     {u'domain': u'xero.com',
#      u'extracted_on': u'2015-05-06',
#      u'uri': u'http://xero.com/add-ons/35-stripe'},
#     {u'domain': u'territorialkansasonline.org',
#      u'extracted_on': u'2015-04-28',
#      u'uri': u'http://territorialkansasonline.org/~imlskto/cgi-bin'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/contact/sales'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/contact'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/help/contact'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/pricing'},
#     {u'domain': u'support.stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://support.stripe.com/questions/migrating-from-balance-to-stripe'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-01',
#      u'uri': u'http://stripe.com/us/pricing'}],
#    u'type': u'generic',
#    u'value': u'sales@stripe.com'},
#   {u'sources': [{u'domain': u'abiusx.com',
#      u'extracted_on': u'2015-07-28',
#      u'uri': u'http://abiusx.com/stripe-ctf-2-web-challenges/'},
#     {u'domain': u'ilmuhacking.com',
#      u'extracted_on': u'2015-01-26',
#      u'uri': u'http://ilmuhacking.com'},
#     {u'domain': u'abiusx.com',
#      u'extracted_on': u'2015-01-28',
#      u'uri': u'http://abiusx.com/stripe-ctf-2-web-challenges'},
#     {u'domain': u'bela-hacker.blogspot.com',
#      u'extracted_on': u'2015-01-28',
#      u'uri': u'http://bela-hacker.blogspot.com'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-02',
#      u'uri': u'http://stripe.com/blog/capture-the-flag'},
#     {u'domain': u'willcodeforfoo.com',
#      u'extracted_on': u'2014-04-23',
#      u'uri': u'http://willcodeforfoo.com'},
#     {u'domain': u'lokola.cz',
#      u'extracted_on': u'2015-03-05',
#      u'uri': u'http://lokola.cz/detail/258278/ramarstvi'},
#     {u'domain': u'fabric.com',
#      u'extracted_on': u'2015-03-04',
#      u'uri': u'http://fabric.com/quilting-fabric-shop-by-designer-moda-fabric-designer-cotton-prints-moda-aspen-frost.aspx'},
#     {u'domain': u'lucy.com',
#      u'extracted_on': u'2015-03-03',
#      u'uri': u'http://lucy.com/on/demandware.store/Sites-Lucy-Site/default/Cart-Show/C894813096'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/events/ctf3-wrap-up-sf'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/events/ctf3-wrap-up-london'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/events/ctf3-kickoff-sf'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/capture-the-flag-20'},
#     {u'domain': u'news.ycombinator.com',
#      u'extracted_on': u'2015-07-03',
#      u'uri': u'http://news.ycombinator.com/item'}],
#    u'type': u'personal',
#    u'value': u'ctf@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/jobs'},
#     {u'domain': u'yostartups.com',
#      u'extracted_on': u'2015-08-30',
#      u'uri': u'http://yostartups.com/cat/compliance/'},
#     {u'domain': u'yostartups.com',
#      u'extracted_on': u'2015-08-30',
#      u'uri': u'http://yostartups.com/cat/finance/'},
#     {u'domain': u'yostartups.com',
#      u'extracted_on': u'2015-08-30',
#      u'uri': u'http://yostartups.com/cat/human-resources/'},
#     {u'domain': u'yostartups.com',
#      u'extracted_on': u'2015-08-30',
#      u'uri': u'http://yostartups.com/cat/marketing/'},
#     {u'domain': u'yostartups.com',
#      u'extracted_on': u'2015-08-30',
#      u'uri': u'http://yostartups.com/cat/media/'},
#     {u'domain': u'api-jobs.com',
#      u'extracted_on': u'2014-04-20',
#      u'uri': u'http://api-jobs.com/designer/zmi3otfhnzetmwmxoc00yjzlltkyyzutndk3yjjhyzuxodni'},
#     {u'domain': u'api-jobs.com',
#      u'extracted_on': u'2014-04-17',
#      u'uri': u'http://api-jobs.com/engineer/mmfjyjnlnzytzdfmys00zwyylwe5zjqtn2exnwfmzwiwmmqx'},
#     {u'domain': u'mantecabulletin.com',
#      u'extracted_on': u'2015-04-26',
#      u'uri': u'http://mantecabulletin.com/archives/section/1'}],
#    u'type': u'generic',
#    u'value': u'jobs@stripe.com'},
#   {u'sources': [{u'domain': u'edge.clearbit.com',
#      u'extracted_on': u'2015-11-04',
#      u'uri': u'http://edge.clearbit.com/docs'},
#     {u'domain': u'ideas.woothemes.com',
#      u'extracted_on': u'2015-01-28',
#      u'uri': u'http://ideas.woothemes.com/forums/133476-woocommerce/suggestions/5713439-stripe-extension-use-or-copy-stripe-checkout'},
#     {u'domain': u'hisroom.com',
#      u'extracted_on': u'2015-04-27',
#      u'uri': u'http://hisroom.com/munsingwear,mens-underwear,big--tall,mun01,039,766,24.html'},
#     {u'domain': u'blog.clearbit.com',
#      u'extracted_on': u'2015-06-09',
#      u'uri': u'http://blog.clearbit.com/streaming-features'},
#     {u'domain': u'clearbit.com',
#      u'extracted_on': u'2015-06-09',
#      u'uri': u'http://clearbit.com/blog'},
#     {u'domain': u'blog.clearbit.com',
#      u'extracted_on': u'2015-06-09',
#      u'uri': u'http://blog.clearbit.com/page/1'},
#     {u'domain': u'blog.clearbit.com',
#      u'extracted_on': u'2015-06-09',
#      u'uri': u'http://blog.clearbit.com'},
#     {u'domain': u'blog.clearbit.com',
#      u'extracted_on': u'2015-06-09',
#      u'uri': u'http://blog.clearbit.com/leadscoring'},
#     {u'domain': u'blog.clearbit.com',
#      u'extracted_on': u'2015-06-09',
#      u'uri': u'http://blog.clearbit.com/page/0'}],
#    u'type': u'personal',
#    u'value': u'lachy@stripe.com'},
#   {u'sources': [{u'domain': u'blogs.abcnews.com',
#      u'extracted_on': u'2015-05-05',
#      u'uri': u'http://blogs.abcnews.com/politicalradar/2007/11/gq-picks-ron-pa.html'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-05-03',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/2'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/open-source-retreat-meetup'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/stripe-open-source-retreat'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/libscore'},
#     {u'domain': u'tripadvisor.com.gr',
#      u'extracted_on': u'2015-05-07',
#      u'uri': u'http://tripadvisor.com.gr/Restaurant_Review-g187147-d1419031-Reviews-Delice_House-Paris_Ile_de_France.html'},
#     {u'domain': u'mpora.com',
#      u'extracted_on': u'2015-04-27',
#      u'uri': u'http://mpora.com/tags/wolfgang-wildner'}],
#    u'type': u'generic',
#    u'value': u'open-source-retreat@stripe.com'},
#   {u'sources': [{u'domain': u'geekfeminism.org',
#      u'extracted_on': u'2015-07-28',
#      u'uri': u'http://geekfeminism.org/2012/04/18/gf-classifieds-april-2012/'},
#     {u'domain': u'geekfeminism.org',
#      u'extracted_on': u'2015-04-26',
#      u'uri': u'http://geekfeminism.org/2012/04/18/gf-classifieds-april-2012'},
#     {u'domain': u'break.com',
#      u'extracted_on': u'2015-03-06',
#      u'uri': u'http://break.com/video/ugc/tall-man-falling-on-ice-8-times-2298294'},
#     {u'domain': u'geekfeminism.org',
#      u'extracted_on': u'2015-05-04',
#      u'uri': u'http://geekfeminism.org/2012/04/18/gf-classifieds-april-2012/comment-page-1'},
#     {u'domain': u'macombdaily.com',
#      u'extracted_on': u'2015-05-03',
#      u'uri': u'http://macombdaily.com/apps/pbcs.dll/article'},
#     {u'domain': u'pokemon.wikia.com',
#      u'extracted_on': u'2015-03-05',
#      u'uri': u'http://pokemon.wikia.com/wiki/Special:Log'},
#     {u'domain': u'maxisciences.com',
#      u'extracted_on': u'2015-04-27',
#      u'uri': u'http://maxisciences.com/scandale'},
#     {u'domain': u'freethoughtblogs.com',
#      u'extracted_on': u'2015-04-27',
#      u'uri': u'http://freethoughtblogs.com/pharyngula/2012/02/23/a-noble-name-and-a-noble-cause/comment-page-1'}],
#    u'type': u'personal',
#    u'value': u'john@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-10-11',
#      u'uri': u'http://stripe.com/blog/page/2'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/12'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/team-activity-in-the-dashboard'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/1'},
#     {u'domain': u'tripadvisor.com.gr',
#      u'extracted_on': u'2015-05-07',
#      u'uri': u'http://tripadvisor.com.gr/Restaurant_Review-g187147-d1419031-Reviews-Delice_House-Paris_Ile_de_France.html'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-02',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'catholic-hierarchy.org',
#      u'extracted_on': u'2015-07-03',
#      u'uri': u'http://catholic-hierarchy.org/bishop/bmozd.html'}],
#    u'type': u'personal',
#    u'value': u'jack.flintermann@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-29',
#      u'uri': u'http://stripe.com/blog/feed.rss'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/12'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/optimizing-dispute-management'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/1'},
#     {u'domain': u'tripadvisor.com.gr',
#      u'extracted_on': u'2015-05-07',
#      u'uri': u'http://tripadvisor.com.gr/Restaurant_Review-g187147-d1419031-Reviews-Delice_House-Paris_Ile_de_France.html'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-29',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'catholic-hierarchy.org',
#      u'extracted_on': u'2015-07-03',
#      u'uri': u'http://catholic-hierarchy.org/bishop/bmozd.html'}],
#    u'type': u'personal',
#    u'value': u'jason.eberle@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-29',
#      u'uri': u'http://stripe.com/blog/feed.rss'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-29',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/12'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/1'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/fraud-reporting'},
#     {u'domain': u'tripadvisor.com.gr',
#      u'extracted_on': u'2015-05-07',
#      u'uri': u'http://tripadvisor.com.gr/Restaurant_Review-g187147-d1419031-Reviews-Delice_House-Paris_Ile_de_France.html'},
#     {u'domain': u'catholic-hierarchy.org',
#      u'extracted_on': u'2015-07-03',
#      u'uri': u'http://catholic-hierarchy.org/bishop/bmozd.html'}],
#    u'type': u'personal',
#    u'value': u'michael.manapat@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-29',
#      u'uri': u'http://stripe.com/blog/feed.rss'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/1'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/smarter-saved-cards'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/12'},
#     {u'domain': u'tripadvisor.com.gr',
#      u'extracted_on': u'2015-05-07',
#      u'uri': u'http://tripadvisor.com.gr/Restaurant_Review-g187147-d1419031-Reviews-Delice_House-Paris_Ile_de_France.html'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-29',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'catholic-hierarchy.org',
#      u'extracted_on': u'2015-07-03',
#      u'uri': u'http://catholic-hierarchy.org/bishop/bmozd.html'}],
#    u'type': u'personal',
#    u'value': u'michelle.bu@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-17',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-20',
#      u'uri': u'http://stripe.com/blog/feed.rss'},
#     {u'domain': u'vxb.com',
#      u'extracted_on': u'2015-03-06',
#      u'uri': u'http://vxb.com/page/bearings/PROD/ShieldedBearing/Kit7744'},
#     {u'domain': u'balibagus.com',
#      u'extracted_on': u'2015-03-05',
#      u'uri': u'http://balibagus.com/reserve.php'},
#     {u'domain': u'mangable.com',
#      u'extracted_on': u'2015-03-04',
#      u'uri': u'http://mangable.com/samurai_deeper_kyo/chapter-306/2'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/5'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-28',
#      u'uri': u'http://stripe.com/blog/multiple-subscriptions'}],
#    u'type': u'personal',
#    u'value': u'jim.danz@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-29',
#      u'uri': u'http://stripe.com/blog/feed.rss'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/1'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/the-new-connect'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/12'},
#     {u'domain': u'tripadvisor.com.gr',
#      u'extracted_on': u'2015-05-07',
#      u'uri': u'http://tripadvisor.com.gr/Restaurant_Review-g187147-d1419031-Reviews-Delice_House-Paris_Ile_de_France.html'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-29',
#      u'uri': u'http://stripe.com/blog'}],
#    u'type': u'personal',
#    u'value': u'brian.krausz@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-29',
#      u'uri': u'http://stripe.com/blog/feed.rss'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/1'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/12'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/preview-subscription-changes'},
#     {u'domain': u'tripadvisor.com.gr',
#      u'extracted_on': u'2015-05-07',
#      u'uri': u'http://tripadvisor.com.gr/Restaurant_Review-g187147-d1419031-Reviews-Delice_House-Paris_Ile_de_France.html'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-29',
#      u'uri': u'http://stripe.com/blog'}],
#    u'type': u'personal',
#    u'value': u'peter.raboud@stripe.com'},
#   {u'sources': [{u'domain': u'support.stripe.com',
#      u'extracted_on': u'2015-08-29',
#      u'uri': u'http://support.stripe.com/questions/considerations-for-platforms-using-connect'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/docs/connect/managed-accounts'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/us/marketplaces'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/docs/connect/connecting-to-accounts'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/marketplaces'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-01',
#      u'uri': u'http://stripe.com/connect'}],
#    u'type': u'generic',
#    u'value': u'connect@stripe.com'},
#   {u'sources': [{u'domain': u'law.cornell.edu',
#      u'extracted_on': u'2015-03-06',
#      u'uri': u'http://law.cornell.edu/supremecourt/text/451/182'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/events/oss-meetup-october-2014'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/events/dublin-intercom-meetup'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/events/montreal-oh-august-2014'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/events/lightning-poutine-august-2014'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-30',
#      u'uri': u'http://stripe.com/events/bayff'}],
#    u'type': u'generic',
#    u'value': u'community@stripe.com'},
#   {u'sources': [{u'domain': u'emailhunter.co',
#      u'extracted_on': u'2015-10-11',
#      u'uri': u'http://emailhunter.co/api/docs'},
#     {u'domain': u'dribbble.com',
#      u'extracted_on': u'2014-04-18',
#      u'uri': u'http://dribbble.com/shots/766770-passport'},
#     {u'domain': u'yellowpagesgoesgreen.org',
#      u'extracted_on': u'2015-03-05',
#      u'uri': u'http://yellowpagesgoesgreen.org/Wellston-OH/Law+Offices+Of+Roy+J+Gilliland/1065023'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/docs/bitcoin'},
#     {u'domain': u'dribbble.com',
#      u'extracted_on': u'2015-05-07',
#      u'uri': u'http://dribbble.com/shots/766770-Passport'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/docs/guides/bitcoin'}],
#    u'type': u'personal',
#    u'value': u'christian@stripe.com'},
#   {u'sources': [{u'domain': u'fuoconcept.com',
#      u'extracted_on': u'2015-11-02',
#      u'uri': u'http://fuoconcept.com/politicas/'},
#     {u'domain': u'solarhomeandrv.com',
#      u'extracted_on': u'2014-04-20',
#      u'uri': u'http://solarhomeandrv.com'},
#     {u'domain': u'tripadvisor.co.kr',
#      u'extracted_on': u'2015-05-03',
#      u'uri': u'http://tripadvisor.co.kr/Hotel_Review-g312725-d1159685-Reviews-Maya_World_Hotel_Belek-Belek_Turkish_Mediterranean_Coast.html'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/security'},
#     {u'domain': u'sunpowerrv.com',
#      u'extracted_on': u'2015-01-27',
#      u'uri': u'http://sunpowerrv.com'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-28',
#      u'uri': u'http://stripe.com/help/security'}],
#    u'type': u'generic',
#    u'value': u'security@stripe.com'},
#   {u'sources': [{u'domain': u'usef.org',
#      u'extracted_on': u'2015-03-05',
#      u'uri': u'http://usef.org/_IFrames/competitions/compSearches/classPoints.aspx'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-03-05',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'apps.who.int',
#      u'extracted_on': u'2015-03-04',
#      u'uri': u'http://apps.who.int/iris/browse'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/four-new-hadoop-projects'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/2'}],
#    u'type': u'personal',
#    u'value': u'colin@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-03-05',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'apps.who.int',
#      u'extracted_on': u'2015-03-04',
#      u'uri': u'http://apps.who.int/iris/browse'},
#     {u'domain': u'usef.org',
#      u'extracted_on': u'2015-03-05',
#      u'uri': u'http://usef.org/_IFrames/competitions/compSearches/classPoints.aspx'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/2'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/pagerduty-analytics-with-pd2pg'}],
#    u'type': u'personal',
#    u'value': u'mark@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-10-11',
#      u'uri': u'http://stripe.com/blog/distributed-ruby-testing'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-10-11',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'github.com',
#      u'extracted_on': u'2015-05-07',
#      u'uri': u'http://github.com/stripe/mosql/blob/v0.1.2/mosql.gemspec'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/events/cambridge-meetup-jun-2014'},
#     {u'domain': u'zillow.com',
#      u'extracted_on': u'2015-06-30',
#      u'uri': u'http://zillow.com/homedetails/3297-Grenfall-Rd-Norton-OH-44203/35378129_zpid'}],
#    u'type': u'personal',
#    u'value': u'nelhage@stripe.com'},
#   {u'sources': [{u'domain': u'yostartups.com',
#      u'extracted_on': u'2015-08-30',
#      u'uri': u'http://yostartups.com/cat/graphic-designer/'},
#     {u'domain': u'dribbble.com',
#      u'extracted_on': u'2014-04-19',
#      u'uri': u'http://dribbble.com/shots/1024005-stripe-api-docs'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'},
#     {u'domain': u'dribbble.com',
#      u'extracted_on': u'2015-03-06',
#      u'uri': u'http://dribbble.com/shots/1024005-Stripe-API-Docs'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/jobs/positions/designer'}],
#    u'type': u'personal',
#    u'value': u'jobs+designer@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-10-11',
#      u'uri': u'http://stripe.com/docs/api'},
#     {u'domain': u'adventuresindevelopment.blogspot.com',
#      u'extracted_on': u'2015-01-31',
#      u'uri': u'http://adventuresindevelopment.blogspot.com'},
#     {u'domain': u'github.com',
#      u'extracted_on': u'2014-04-16',
#      u'uri': u'http://github.com/drone/go.stripe/blob/12a21f3f44aafcee576e9f0197646d06217ac08c/customer_test.go'},
#     {u'domain': u'adventuresindevelopment.blogspot.com',
#      u'extracted_on': u'2015-07-28',
#      u'uri': u'http://adventuresindevelopment.blogspot.com/2012/05/handle-http-form-post-requests-to-wcf.html'},
#     {u'domain': u'milfordbeacon.com',
#      u'extracted_on': u'2015-05-06',
#      u'uri': u'http://milfordbeacon.com/article/20130215/NEWS/302159963/1664/ENTERTAINMENTLIFE'}],
#    u'type': u'generic',
#    u'value': u'site@stripe.com'},
#   {u'sources': [{u'domain': u'amberonrails.com',
#      u'extracted_on': u'2015-09-01',
#      u'uri': u'http://amberonrails.com/move-fast-dont-break-your-api'},
#     {u'domain': u'amberonrails.com',
#      u'extracted_on': u'2015-09-01',
#      u'uri': u'http://amberonrails.com/'},
#     {u'domain': u'amberonrails.com',
#      u'extracted_on': u'2015-09-01',
#      u'uri': u'http://amberonrails.com'},
#     {u'domain': u'amberonrails.com',
#      u'extracted_on': u'2015-09-01',
#      u'uri': u'http://amberonrails.com/building-stripes-api'},
#     {u'domain': u'thisismoney.co.uk',
#      u'extracted_on': u'2015-03-06',
#      u'uri': u'http://thisismoney.co.uk/money/pensions/article-2645268/Workers-freed-pool-retirement-savings-savings-Dutch-style-collective-pensions-bring-economies-scale-reduce-risk.html'}],
#    u'type': u'personal',
#    u'value': u'amber@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-10-11',
#      u'uri': u'http://stripe.com/blog/apple-pay/'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/apple-pay'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/2'},
#     {u'domain': u'mpora.com',
#      u'extracted_on': u'2015-04-27',
#      u'uri': u'http://mpora.com/tags/wolfgang-wildner'}],
#    u'type': u'personal',
#    u'value': u'apple-pay@stripe.com'},
#   {u'sources': [{u'domain': u'usef.org',
#      u'extracted_on': u'2015-03-05',
#      u'uri': u'http://usef.org/_IFrames/competitions/compSearches/classPoints.aspx'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-03-05',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/scaling-email-transparency'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/2'}],
#    u'type': u'personal',
#    u'value': u'oss@stripe.com'},
#   {u'sources': [{u'domain': u'github.com',
#      u'extracted_on': u'2015-07-28',
#      u'uri': u'http://github.com/stripe/stripe-python/blob/v1.5.32/changelog'},
#     {u'domain': u'fr.wikipedia.org',
#      u'extracted_on': u'2015-05-04',
#      u'uri': u'http://fr.wikipedia.org/wiki/Coupe_de_Bakou'},
#     {u'domain': u'flickr.com',
#      u'extracted_on': u'2015-03-06',
#      u'uri': u'http://flickr.com/photos/worldworldworld/4983774359'},
#     {u'domain': u'idahoptv.org',
#      u'extracted_on': u'2015-05-06',
#      u'uri': u'http://idahoptv.org/schedules/listings.cfm'}],
#    u'type': u'personal',
#    u'value': u'anurag@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-10-11',
#      u'uri': u'http://stripe.com/docs/guides/alipay'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/stripe-alipay'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/3'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/docs/guides/alipay-beta'}],
#    u'type': u'personal',
#    u'value': u'alipay@stripe.com'},
#   {u'sources': [{u'domain': u'investor.visa.com',
#      u'extracted_on': u'2015-09-09',
#      u'uri': u'http://investor.visa.com/rss/pressrelease.aspx'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/press/alipay'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/about/press'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/press'}],
#    u'type': u'generic',
#    u'value': u'media@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-17',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-20',
#      u'uri': u'http://stripe.com/blog/feed.rss'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-29',
#      u'uri': u'http://stripe.com/blog/checkout-new-features'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/4'}],
#    u'type': u'personal',
#    u'value': u'lachy.groom@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-17',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-20',
#      u'uri': u'http://stripe.com/blog/feed.rss'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/5'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-03',
#      u'uri': u'http://stripe.com/blog/open-betas-in-europe'}],
#    u'type': u'personal',
#    u'value': u'michelle+intl@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-17',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-20',
#      u'uri': u'http://stripe.com/blog/feed.rss'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/dynamic-descriptors'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/4'}],
#    u'type': u'personal',
#    u'value': u'jbalogh+descriptors@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-17',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-20',
#      u'uri': u'http://stripe.com/blog/feed.rss'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/new-currencies'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/5'}],
#    u'type': u'generic',
#    u'value': u'thairu+currencies@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-20',
#      u'uri': u'http://stripe.com/blog/feed.rss'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/events-in-melbourne-and-sydney'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/5'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-17',
#      u'uri': u'http://stripe.com/blog'}],
#    u'type': u'personal',
#    u'value': u'susan+feedback@stripe.com'},
#   {u'sources': [{u'domain': u'wiki.haskell.org',
#      u'extracted_on': u'2015-07-02',
#      u'uri': u'http://wiki.haskell.org'},
#     {u'domain': u'nyjetsfan.com',
#      u'extracted_on': u'2015-03-06',
#      u'uri': u'http://nyjetsfan.com/forum2'},
#     {u'domain': u'btn.com',
#      u'extracted_on': u'2015-04-27',
#      u'uri': u'http://btn.com/2012/02/07/dienhart-get-your-big-ten-player-rankings'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-07-28',
#      u'uri': u'http://stripe.com/docs/upgrades'}],
#    u'type': u'generic',
#    u'value': u'support+coupon@stripe.com'},
#   {u'sources': [{u'domain': u'cryptome.org',
#      u'extracted_on': u'2015-01-27',
#      u'uri': u'http://cryptome.org/2014/04/the-intercept-comsec.htm'},
#     {u'domain': u'mschade.me',
#      u'extracted_on': u'2014-04-16',
#      u'uri': u'http://mschade.me'},
#     {u'domain': u'sfnewtech.com',
#      u'extracted_on': u'2014-04-19',
#      u'uri': u'http://sfnewtech.com/category/60secondspots'},
#     {u'domain': u'sfnewtech.com',
#      u'extracted_on': u'2015-06-19',
#      u'uri': u'http://sfnewtech.com/2012/10/11/60-second-spots-from-10-10-are-here'}],
#    u'type': u'personal',
#    u'value': u'michael@stripe.com'},
#   {u'sources': [{u'domain': u'twiends.com',
#      u'extracted_on': u'2015-01-30',
#      u'uri': u'http://twiends.com/funnypostssiri/-dir'},
#     {u'domain': u'twiends.com',
#      u'extracted_on': u'2015-01-25',
#      u'uri': u'http://twiends.com/funnypostssiri/-twitter'},
#     {u'domain': u'twiends.com',
#      u'extracted_on': u'2015-01-26',
#      u'uri': u'http://twiends.com/funnypostssiri/-cycle'},
#     {u'domain': u'twiends.com',
#      u'extracted_on': u'2015-01-28',
#      u'uri': u'http://twiends.com/funnypostssiri'}],
#    u'type': u'generic',
#    u'value': u'questions@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/blog/page/2'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/6'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/track-account-activity-in-the-dashboard'}],
#    u'type': u'personal',
#    u'value': u'russell+blog@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/blog/page/2'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/5'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/new-capabilities-for-connect'}],
#    u'type': u'personal',
#    u'value': u'amber.feng@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/blog/page/2'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/adding-context-with-metadata'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/6'}],
#    u'type': u'personal',
#    u'value': u'kiran@stripe.com'},
#   {u'sources': [{u'domain': u'yostartups.com',
#      u'extracted_on': u'2015-08-30',
#      u'uri': u'http://yostartups.com/cat/human-resources/'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/jobs/positions/recruiter'}],
#    u'type': u'personal',
#    u'value': u'jobs+recruiter@stripe.com'},
#   {u'sources': [{u'domain': u'yostartups.com',
#      u'extracted_on': u'2015-08-30',
#      u'uri': u'http://yostartups.com/cat/marketing/'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/jobs/positions/account-executive'}],
#    u'type': u'generic',
#    u'value': u'jobs+account-executive@stripe.com'},
#   {u'sources': [{u'domain': u'cityprintsmapart.com',
#      u'extracted_on': u'2015-10-08',
#      u'uri': u'http://cityprintsmapart.com/privacy-policy/'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-20',
#      u'uri': u'http://stripe.com/us/privacy'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/privacy'}],
#    u'type': u'generic',
#    u'value': u'safeharbor@stripe.com'},
#   {u'sources': [{u'domain': u'dribbble.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://dribbble.com/shots/736405-stripe-teams'},
#     {u'domain': u'dribbble.com',
#      u'extracted_on': u'2014-04-18',
#      u'uri': u'http://dribbble.com/shots/736410-stripe-in-canada'},
#     {u'domain': u'dribbble.com',
#      u'extracted_on': u'2015-05-06',
#      u'uri': u'http://dribbble.com/shots/736405-Stripe-Teams'}],
#    u'type': u'personal',
#    u'value': u'ludwig@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/blog/page/2'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/official-nodejs-support'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/6'}],
#    u'type': u'personal',
#    u'value': u'james@stripe.com'},
#   {u'sources': [{u'domain': u'support.stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://support.stripe.com/questions/is-stripe-available-in-denmark'},
#     {u'domain': u'support.stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://support.stripe.com/questions/is-stripe-available-in-denmark-how-do-i-sign-up-for-the-beta'}],
#    u'type': u'personal',
#    u'value': u'connect+dk@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/send-money-to-debit-cards'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/4'}],
#    u'type': u'personal',
#    u'value': u'stephen.wan@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/send-money-to-debit-cards'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/blog/page/4'}],
#    u'type': u'personal',
#    u'value': u'siddarth@stripe.com'},
#   {u'sources': [{u'domain': u'investor.visa.com',
#      u'extracted_on': u'2015-09-09',
#      u'uri': u'http://investor.visa.com/rss/pressrelease.aspx'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/help/contact'}],
#    u'type': u'personal',
#    u'value': u'kelly@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/jobs/positions/account-support'}],
#    u'type': u'generic',
#    u'value': u'jobs+account-support@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/jobs/positions/engineer'}],
#    u'type': u'personal',
#    u'value': u'jobs+engineer@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/jobs/positions/country-lead'}],
#    u'type': u'personal',
#    u'value': u'jobs+country-lead@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-04-26',
#      u'uri': u'http://stripe.com/au/privacy'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-20',
#      u'uri': u'http://stripe.com/us/privacy'}],
#    u'type': u'generic',
#    u'value': u'privacy@stripe.com'},
#   {u'sources': [{u'domain': u'insomanic.me.uk',
#      u'extracted_on': u'2014-04-19',
#      u'uri': u'http://insomanic.me.uk'},
#     {u'domain': u'insomanic.me.uk',
#      u'extracted_on': u'2014-04-19',
#      u'uri': u'http://insomanic.me.uk/post/48127029333/im-joining-stripe'}],
#    u'type': u'personal',
#    u'value': u'ay@stripe.com'},
#   {u'sources': [{u'domain': u'shop.stripe.com',
#      u'extracted_on': u'2015-09-09',
#      u'uri': u'http://shop.stripe.com/'},
#     {u'domain': u'shop.stripe.com',
#      u'extracted_on': u'2015-09-09',
#      u'uri': u'http://shop.stripe.com'}],
#    u'type': u'personal',
#    u'value': u'shop@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-17',
#      u'uri': u'http://stripe.com/blog'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-20',
#      u'uri': u'http://stripe.com/blog/feed.rss'}],
#    u'type': u'generic',
#    u'value': u'support+heartbleed@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/events/melbourne-tech-talk'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/events/sydney-tech-talk'}],
#    u'type': u'personal',
#    u'value': u'australia@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-16',
#      u'uri': u'http://stripe.com/docs/examples'},
#     {u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-17',
#      u'uri': u'http://stripe.com/docs/libraries'}],
#    u'type': u'personal',
#    u'value': u'dev@stripe.com'},
#   {u'sources': [{u'domain': u'ideas.repec.org',
#      u'extracted_on': u'2015-03-04',
#      u'uri': u'http://ideas.repec.org/p/nbr/nberwo/10599.html'},
#     {u'domain': u'moz.com',
#      u'extracted_on': u'2015-06-09',
#      u'uri': u'http://moz.com/perks'}],
#    u'type': u'personal',
#    u'value': u'discount+seomoz@stripe.com'},
#   {u'sources': [{u'domain': u'patrickcollison.com',
#      u'extracted_on': u'2015-10-13',
#      u'uri': u'http://patrickcollison.com/svhistory'},
#     {u'domain': u'trendsmap.com',
#      u'extracted_on': u'2015-01-31',
#      u'uri': u'http://trendsmap.com/local/us/san+francisco'}],
#    u'type': u'personal',
#    u'value': u'patrick@stripe.com'},
#   {u'sources': [{u'domain': u'support.stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://support.stripe.com/questions/is-stripe-available-in-germany'}],
#    u'type': u'personal',
#    u'value': u'connect+de@stripe.com'},
#   {u'sources': [{u'domain': u'support.stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://support.stripe.com/questions/is-stripe-available-in-france'}],
#    u'type': u'personal',
#    u'value': u'connect+fr@stripe.com'},
#   {u'sources': [{u'domain': u'support.stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://support.stripe.com/questions/is-stripe-available-in-finland'}],
#    u'type': u'personal',
#    u'value': u'connect+fi@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/subscriptions'}],
#    u'type': u'generic',
#    u'value': u'subscriptions@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-06-10',
#      u'uri': u'http://stripe.com/docs/libraries'}],
#    u'type': u'generic',
#    u'value': u'docs@stripe.com'},
#   {u'sources': [{u'domain': u'causes.com',
#      u'extracted_on': u'2015-03-05',
#      u'uri': u'http://causes.com/help'}],
#    u'type': u'personal',
#    u'value': u'upport@stripe.com'},
#   {u'sources': [{u'domain': u'kicker.de',
#      u'extracted_on': u'2015-03-06',
#      u'uri': u'http://kicker.de/news/fussball/intligen/intwettbewerbe/mexiko-play-off/2012-13/0/-1/spieltag.html'}],
#    u'type': u'personal',
#    u'value': u'trong@stripe.com'},
#   {u'sources': [{u'domain': u'kicker.de',
#      u'extracted_on': u'2015-03-06',
#      u'uri': u'http://kicker.de/news/fussball/intligen/intwettbewerbe/mexiko-play-off/2012-13/0/-1/spieltag.html'}],
#    u'type': u'personal',
#    u'value': u'tavish@stripe.com'},
#   {u'sources': [{u'domain': u'kicker.de',
#      u'extracted_on': u'2015-03-06',
#      u'uri': u'http://kicker.de/news/fussball/intligen/intwettbewerbe/mexiko-play-off/2012-13/0/-1/spieltag.html'}],
#    u'type': u'personal',
#    u'value': u'tavish.armstrong@stripe.com'},
#   {u'sources': [{u'domain': u'kicker.de',
#      u'extracted_on': u'2015-03-06',
#      u'uri': u'http://kicker.de/news/fussball/intligen/intwettbewerbe/mexiko-play-off/2012-13/0/-1/spieltag.html'}],
#    u'type': u'personal',
#    u'value': u'tarmstrong@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2015-03-06',
#      u'uri': u'http://stripe.com/us/marketplaces'}],
#    u'type': u'generic',
#    u'value': u'marketplaces@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'personal',
#    u'value': u'jobs+pr@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'personal',
#    u'value': u'jobs+risk@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'personal',
#    u'value': u'jobs+rc@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'personal',
#    u'value': u'jobs+bd@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'personal',
#    u'value': u'jobs+reliability-engineer@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'personal',
#    u'value': u'jobs+product-engineer@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'personal',
#    u'value': u'jobs+infrastructure-engineer@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'personal',
#    u'value': u'jobs+data@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'personal',
#    u'value': u'jobs+engineering-intern@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'generic',
#    u'value': u'jobs+au-developer-relations@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'personal',
#    u'value': u'jobs+au-engineer@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'generic',
#    u'value': u'jobs+au-account-support@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'generic',
#    u'value': u'jobs+au-account-executive@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'generic',
#    u'value': u'jobs+eu-support@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'generic',
#    u'value': u'jobs+eu-account-support@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'generic',
#    u'value': u'jobs+eu-developer-relations@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'personal',
#    u'value': u'jobs+eu-engineer@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'personal',
#    u'value': u'jobs+eu-risk@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'generic',
#    u'value': u'jobs+eu-account-executive@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'generic',
#    u'value': u'jobs+support-engineer@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'personal',
#    u'value': u'jobs+paralegal@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'personal',
#    u'value': u'jobs+receptionist@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-21',
#      u'uri': u'http://stripe.com/jobs'}],
#    u'type': u'generic',
#    u'value': u'jobs+weekend-support@stripe.com'},
#   {u'sources': [{u'domain': u'twopcharts.com',
#      u'extracted_on': u'2014-04-20',
#      u'uri': u'http://twopcharts.com/favorites'}],
#    u'type': u'personal',
#    u'value': u'kat@stripe.com'},
#   {u'sources': [{u'domain': u'stripe.com',
#      u'extracted_on': u'2014-04-18',
#      u'uri': u'http://stripe.com/docs/connect/oauth'}],
#    u'type': u'personal',
#    u'value': u'you@stripe.com'},
#   {u'sources': [{u'domain': u'nshipster.com',
#      u'extracted_on': u'2015-01-29',
#      u'uri': u'http://nshipster.com/feed.xml'}],
#    u'type': u'personal',
#    u'value': u'jack@stripe.com'},
#   {u'sources': [{u'domain': u'nshipster.com',
#      u'extracted_on': u'2015-01-29',
#      u'uri': u'http://nshipster.com/feed.xml'}],
#    u'type': u'personal',
#    u'value': u'jack+nshipster@stripe.com'}],
#  u'offset': 0,
#  u'pattern': u'{first}',
#  u'results': 174,
#  u'status': u'success',
#  u'webmail': False}
