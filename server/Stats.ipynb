# %%
import arrow
import rethinkdb as r
import pandas as pd

# %%
from rq import Queue
from worker import conn as _conn
q = Queue("low", connection=_conn)
default_q = Queue("default", connection=_conn)
high_q = Queue("high", connection=_conn)

# %%
j = q.jobs

# %%
j2 = q.jobs

# %%
len(j)
# Out:
# 55607

# %%
arrow.utcnow().timestamp
# Out:
# 1445659892

# %%
=
# Out:
# 55607

# %%
RETHINKDB_HOST="rethinkdb_tunnel"
RETHINKDB_AUTH_KEY="PPxYaDVvVmDhXccvM2qdGzFhyIdwcLpYSuyGIbTFD5c" 
RETHINKDB_DB="triggeriq"
#REDIS_URL=redis://x:AUMYHVZWLNTWYLUJ@aws-us-east-1-portal.8.dblayer.com:10419

# %%
conn = r.connect(
  #host='rethinkdb_tunnel',
  host= RETHINKDB_HOST,
  port= 28015,
  db= RETHINKDB_DB,
  auth_key= RETHINKDB_AUTH_KEY
)
# Out:
# ---------------------------------------------------------------------------
# ReqlDriverError                           Traceback (most recent call last)
# <ipython-input-287-ea7352c63dba> in <module>()
#       4   port= 28015,
#       5   db= RETHINKDB_DB,
# ----> 6   auth_key= RETHINKDB_AUTH_KEY
#       7 )
#
# /Users/robin/anaconda/lib/python2.7/site-packages/rethinkdb/net.pyc in connect(host, port, db, auth_key, timeout, ssl, **kwargs)
#     603     global connection_type
#     604     conn = connection_type(host, port, db, auth_key, timeout, ssl, **kwargs)
# --> 605     return conn.reconnect(timeout=timeout)
#     606
#     607 def set_loop_type(library):
#
# /Users/robin/anaconda/lib/python2.7/site-packages/rethinkdb/net.pyc in reconnect(self, noreply_wait, timeout)
#     530
#     531         self._instance = self._conn_type(self, **self._child_kwargs)
# --> 532         return self._instance.connect(timeout)
#     533
# ...

# %%
j = q.jobs
j2 = q.jobs

ids = [i.id for i in j]
_ids = [i.id for i in j2]
    
number_of_new_jobs_added = len(_ids) - _ids.index(ids[-1])
number_of_jobs_finished = ids.index(_ids[0])
# Out:
# 1523

# %%
old, new = j, j2
# run every second

# %%
# read timestamp, old from pickle
new = q.jobs
timestamp = arrow.utcnow().timestamp

ids = [i.id for i in old]
_ids = [i.id for i in new]

number_of_new_jobs_added = len(_ids) - _ids.index(ids[-1])
number_of_jobs_finished = ids.index(_ids[0])

# store timestamp, new in pickle

# %%
from simmetrica import Simmetrica

# %%
from simmetrica import Simmetrica
simmetrica = Simmetrica()
simmetrica.push('add-cart-action')
# Out:
# [4L, 4L, 3L, 4L, 3L, 4L, 4L, 4L]

# %%
start = simmetrica.get_current_timestamp() - 600
end = simmetrica.get_current_timestamp()
results = simmetrica.query('add-cart-action', start, end, 'min')
for time, val in results:
    print time, val
# Out:
# 1445661120 0
# 1445661180 0
# 1445661240 0
# 1445661300 0
# 1445661360 0
# 1445661420 0
# 1445661480 0
# 1445661540 1
# 1445661600 0
# 1445661660 3

# %%
j[0]
# Out:
# Job(u'0e0baf04-d090-4e22-9647-840ea4e0eae9', enqueued_at=datetime.datetime(2015, 10, 23, 19, 24, 21))

# %%
import datetime

# %%
arrow.get(datetime.datetime(2015, 10, 23, 19, 24, 21)).humanize()
# Out:
# u'9 hours ago'

# %%
import time
start_time = time.time()
main()
print("--- %s seconds ---" % (time.time() - start_time))

# %%
arrow.get(1445824926).humanize()
# Out:
# u'a minute ago'

# %%
import redis
import os

# %%
rd = redis.Redis()

# %%
rd = redis.from_url("redis://x:AUMYHVZWLNTWYLUJ@aws-us-east-1-portal.8.dblayer.com:10419")

# %%
rd = redis.from_url(os.getenv('REDIS_URL', 'redis://localhost:6379'))

# %%
print rd.zrange("function:time:company_name_to_domain", 0, -1, withscores=True)
print rd.zrange("function:time:clearbit_search_company_record", 0, -1, withscores=True)
print rd.zrange("function:time:bulk_update_employee_record", 0, -1, withscores=True)
print rd.zrange("function:time:company_employee_search", 0, -1, withscores=True)
print rd.zrange("function:time:simplyhired_job_scrape", 0, -1, withscores=True)
print rd.zrange("function:time:indeed_job_scrape", 0, -1, withscores=True)
print rd.zrange("function:time:ziprecruiter_job_scrape", 0, -1, withscores=True)
# Out:
# []
# []
# []
# []
# []
# []
# []

# %%
i = pd.DataFrame(rd.zrange("function:time:indeed_job_scrape", 0, -1, withscores=True)).astype("float")

# %%
i[0].mean()
i[0].median()
i[0].min()
i[0].max()
len(i[0])
len(i[0]) / (i[1].max() - i[1].min() / 10**6)
# Out:
# 69

# %%
len(zr)
# Out:
# 0

# %%
metrics = ["function:time:company_name_to_domain",
      "function:time:clearbit_search_company_record",
      "function:time:bulk_update_employee_record",
      "function:time:company_employee_search",
      "function:time:simplyhired_job_scrape",
      "function:time:indeed_job_scrape",
      "function:time:ziprecruiter_job_scrape"]

for m in metrics:
    zr = pd.DataFrame(rd.zrange(m, 0, -1, withscores=True)).astype("float")
    print len(zr)
    if len(zr): break
    continue
    if zr.empty: continue
    zr.columns = ["a","b"]
    data = {"mean": zr.a.mean(),
           "median":  zr.a.median(),
           "min":   zr.a.min(),
           "max":   zr.a.max(),
           "amount":   len(zr.a),
           "raw":     zr.to_dict("r"),
           "per_second":   len(zr.a) / (zr.b.max() - zr.b.min() / 10**6)}
    #p.trigger('admin_dashboard', m, data)
# Out:
# 0
# 0
# 0
# 0
# 276

# %%
arrow.get([-10:]).humanize()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-193-8b2ac3eda491> in <module>()
# ----> 1 arrow.get(list(zr[1])[-10:]).humanize()
#
# /Users/robin/anaconda/lib/python2.7/site-packages/arrow/api.pyc in get(*args, **kwargs)
#      21     '''
#      22
# ---> 23     return _factory.get(*args, **kwargs)
#      24
#      25 def utcnow():
#
# /Users/robin/anaconda/lib/python2.7/site-packages/arrow/factory.pyc in get(self, *args, **kwargs)
#     167
#     168             else:
# --> 169                 raise TypeError('Can\'t parse single argument type of \'{0}\''.format(type(arg)))
#     170
#     171         elif arg_count == 2:
#
# TypeError: Can't parse single argument type of '<type 'list'>'

# %%
for i in zr[1][-15:]:
    print arrow.get(i).humanize()
# Out:
# 7 minutes ago
# 7 minutes ago
# 7 minutes ago
# 7 minutes ago
# 7 minutes ago
# 7 minutes ago
# 6 minutes ago
# 6 minutes ago
# 6 minutes ago
# 6 minutes ago
# 6 minutes ago
# 6 minutes ago
# 6 minutes ago
# 6 minutes ago
# 6 minutes ago

# %%
(i[1].max() - i[1].min())/ 10**6
# Out:
# 0.000413

# %%
-

q = Queue("low", connection=_conn)
dq = Queue("default", connection=_conn)
hq = Queue("high", connection=_conn)

# %%
arrow.get("1446500717.0").humanize()
# Out:
# u'a minute ago'

# %%
start_time = time.time()

# %%
redis.Redis().zadd("function:time:indeed_job_scrape",
                   str((time.time() - start_time)*10**6),
                   arrow.now().timestamp)
# Out:
# 1

# %%
#TODO - add employees

# %%
conn = r.connect(db="triggeriq")
t = list(r.table("triggers").run(conn))

# %%
p = pd.DataFrame(pd.DataFrame(t).email_pattern.dropna().tolist()).pattern.drop_duplicates().tolist()

# %%
for i in p:
    if not i:
         continue
    if "{" in i and i:
        print i.format(**{"first":"{{first}}","last":"{{last}}","f":"{{first_initial}}","l":"{{last_initial}}"})
# Out:
# {{first}}_{{last}}
# {{first}}.{{last}}
# {{first_initial}}{{last}}
# {{first}}
# {{last}}
# {{first_initial}}.{{last}}
# {{last}}.{{first}}
# {{first}}{{last_initial}}

# %%
conn = r.connect(db="triggeriq")
p = list(r.table("prospect_profiles").run(conn))

# %%
r.table("prospect_profiles").insert({"name":"inside sales", "profiles": [{u'className': u'HiringProfile',
    u'locales': [],
    u'roles': [u'inside sales']}],"titles":["sales"]}).run(conn)
# Out:
# {u'deleted': 0,
#  u'errors': 0,
#  u'generated_keys': [u'c2a9d9fb-a1ff-486d-aef5-62abcb111b59'],
#  u'inserted': 1,
#  u'replaced': 0,
#  u'skipped': 0,
#  u'unchanged': 0}

# %%
for i in p:
    del i["id"]

# %%
p
# Out:
# [{u'name': u'inside sales',
#   u'profiles': [{u'className': u'HiringProfile',
#     u'locales': [],
#     u'roles': [u'inside sales']}],
#   u'titles': [u'sales']},
#  {u'name': u'First',
#   u'profiles': [{u'className': u'HiringProfile',
#     u'locales': [],
#     u'roles': [u'inside sales']}]},
#  {u'name': u'First',
#   u'profiles': [{u'className': u'HiringProfile',
#     u'locales': [],
#     u'roles': [u'ios developer']}]}]

# %%
import rethinkdb as r

# %%
conn = r.connect(db="socialiq")
e = pd.DataFrame(list(r.table("instagram_profiles").run(conn)))

# %%
triggers = r.table("triggers").coerce_to("array").run(conn)

# %%
t = pd.DataFrame(triggers)

# %%
t
# Out:
#      company_domain_research_completed company_domain_research_result  \
# 0     2015-11-02 20:23:58.090000+00:00                          found
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# 5                                  NaN                            NaN
# 6                                  NaN                            NaN
# 7                                  NaN                            NaN
# 8                                  NaN                            NaN
# 9                                  NaN                            NaN
# 10                                 NaN                            NaN
# 11                                 NaN                            NaN
# ...

# %%
    conn = rethink_conn.conn()
    triggers = r.table("triggers").coerce_to("array").run(conn)
    for val in triggers:
        if "domain" not in val.keys():
            dq.enqueue(CompanyNameToDomain()._update_company_record,
                      val["company_name"], val["company_key"])
            dq.enqueue(GoogleEmployeeSearch()._update_employee_record,
                      val["company_name"], "", val["company_key"])
            continue
        args = [val["domain"], val["company_key"]]
        cdrc = "company_domain_research_completed"
        ehsc = "emailhunter_search_completed"
        dq.enqueue(ClearbitSearch()._update_company_record, *args)
        hq.enqueue(EmailHunter()._update_record, *args)

# %%
from scraping.company_api.company_name_to_domain import CompanyNameToDomain
urls = CompanyNameToDomain()._make_urls("GuideSpark")

# %%
urls = CompanyNameToDomain()._make_urls("GuideSpark")

# %%
import urllib
import urlparse

# %%
import tornado.httpclient

def handle_request(response):
    print response.url
    print CompanyNameToDomain()._persist(response)
    # persist to rethinkdb
    
http_client = tornado.httpclient.AsyncHTTPClient()
triggers = list(r.table("triggers").run(conn))
for trigger in triggers:
    for url in CompanyNameToDomain()._make_urls(trigger["company_name"]):
        http_client.fetch(url, handle_request)
# Out:
# [{'link_span': u"www.guidespark.comGuideSpark's employee engagement & internal communication platform transforms employee communications via engaging & customized contents. Learn more.", 'link_text': u'GuideSpark - Employee Engagement & Internal \u2026', 'link': u'http://www.guidespark.com/', 'engine_url': 'http://customero:iUyET3ErxR@paygo.crawlera.com/fetch?url=http%3A%2F%2Fwww.bing.com%2Fsearch%3Fq%3Dguidespark'}, {'link_span': u'www.guidespark.com/aboutAbout GuideSpark. GuideSpark is the future of employee communications. Our robust SaaS communications platform, which includes customized, consistent, and cost ...', 'link_text': u'About GuideSpark GuideSpark', 'link': u'http://www.guidespark.com/about/', 'engine_url': 'http://customero:iUyET3ErxR@paygo.crawlera.com/fetch?url=http%3A%2F%2Fwww.bing.com%2Fsearch%3Fq%3Dguidespark'}, {'link_span': u"www.forbes.com/companies/guidesparkGuidespark #88 on the Forbes America's Most Promising Companies List", 'link_text': u"Guidespark on the
# ...

# %%
import tornado.httpclient

def handle_request(response):
    print response.effective_url
    if response.error:
        print "Error:", response.error
    else:
        print """ response.body """

http_client = tornado.httpclient.AsyncHTTPClient()
for i in range(10):
    http_client.fetch("http://www.google.com/?q=tornado", handle_request)
# Out:
#  response.body
# http://www.google.ca/?q=tornado&gws_rd=cr&ei=-h46VuumDsOxe-X3vIgB
#  response.body
# http://www.google.ca/?q=tornado&gws_rd=cr&ei=-h46Vr3PDYG1eKnaurAC
#  response.body
# http://www.google.ca/?q=tornado&gws_rd=cr&ei=_R46VsXPB4SleojUnJgH
#  response.body
# http://www.google.ca/?q=tornado&gws_rd=cr&ei=_R46VuHkB8fLeIrlj4AM
#  response.body
# http://www.google.ca/?q=tornado&gws_rd=cr&ei=_R46Vq2FCMvYeu_miJAH
#  response.body
# http://www.google.ca/?q=tornado&gws_rd=cr&ei=_R46Vs2XCMbbe_i3gpgO
#  response.body
# http://www.google.ca/?q=tornado&gws_rd=cr&ei=_R46VsDOCMWyeP2JrPgC
#  response.body
# http://www.google.ca/?q=tornado&gws_rd=cr&ei=_R46VsXoCMm2eK7ghoAD
#  response.body
# http://www.google.ca/?q=tornado&gws_rd=cr&ei=_R46VtL5CIjseb6ptogB
#  response.body
# http://www.google.ca/?q=tornado&gws_rd=cr&ei=_R46VpKXCYive7rMkKAJ
#  response.body
# http://www.google.ca/?q=tornado&gws_rd=cr&ei=_R46VryrCcHIesabv6AM

# %%
un, pw = "customero", "iUyET3ErxR"
cloak = "http://{0}:{1}@paygo.crawlera.com/fetch".format(un, pw)
#headers = {"X-Mashape-Key": "pdL7tBtCRXmshjM0GeRxnbyhpWzNp13kguyjsnxPTjSv8foPKA"}
url = "https://www.google.com/search?q=site%3Ainstagram.com+%223.6K+followers%22&start=0&num=100&filter=0"
url = 'https://www.google.com/search?q=site:instagram.com+"223.6K+followers"&start=0&num=100&filter=0'
r = requests.get(cloak, params={'url':url})

# %%
import urllib

# %%
r = requests.get(cloak+"?"+urllib.urlencode({"url":url}))

# %%
r
# Out:
# <Response [200]>

# %%
conn

# %%
import rethinkdb as r

# %%
a = pd.DataFrame(list(r.db("socialiq").table("instagram_profiles").run(conn)))
print a.url.drop_duplicates().shape
print a.link.drop_duplicates().shape
# Out:
# (47008,)
# (47969,)

# %%
conn = r.connect(db="triggeriq")

# %%
t = pd.DataFrame(list(r.table("triggers").run(conn)))
t[t.domain.isnull()].shape
# Out:
# (643, 17)

# %%
t[t.domain.isnull()].company_name.drop_duplicates().shape
# Out:
# (399,)

# %%
t[t.domain.isnull()].shape
# Out:
# (647, 17)

# %%
t = pd.DataFrame(list(r.table("triggers").run(conn)))
t[t.domain.isnull()].shape
# Out:
# (647, 17)

# %%
import rethinkdb as r

# %%
conn = r.connect(db="triggeriq")

# %%
t = pd.DataFrame(list(r.table("triggers").run(conn)))

# %%
t = pd.DataFrame(list(r.table("triggers").run(conn)))
t[t.domain.isnull()].shape
# Out:
# (341, 17)

# %%
arrow.get(1445747944).humanize()
# Out:
# u'11 days ago'

# %%
arrow.get(1446678249 ).humanize()
# Out:
# u'18 hours ago'

# %%
1445747944 > 1446678241
# Out:
# False

# %%
t.sort("createdAt",ascending=False).head(50).shape
# Out:
# /Users/robin/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
# (50, 17)

# %%
t.domain.value_counts()
# Out:
# linkedin.com                       40
# statefarm.com                      15
# wikipedia.org                      14
# facebook.com                       11
# guidespark.com                     10
# indeed.com                          9
# glassdoor.com                       7
# dice.com                            6
# monster.com                         5
# yellowpages.com                     5
# careerbuilder.com                   5
# yelp.com                            4
# accenture.com                       3
# amazon.cn                           3
# apexsecurity.us                     3
# cisco.com                           3
# manta.com                           3
# graybar.com                         3
# merriam-webster.com                 3
# precisionsystems.com                3
# bcinteriors.com                     2
# nlcloans.com                        2
# sirva.com                           2
# operationit.com                     2
# chghealthcare.com                   2
# ...

# %%
t[t.company_name == 100]
# Out:
# Empty DataFrame
# Columns: [company_domain_research_completed, company_domain_research_result, company_key, company_name, createdAt, date, domain, email_pattern, emailhunter_search_completed, job_title, keyword, link, location, profile, source, summary, timestamp]
# Index: []

# %%
from scraping.company_api.company_name_to_domain import CompanyNameToDomain

# %%
cdr = pd.DataFrame(list(r.table("company_domain_research").run(conn)))

# %%
dfs = [pd.DataFrame(i) for i in cdr[cdr.qry.str.contains("Admar Supply")].res.tolist()]

# %%
t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b7269fa25085> in <module>()
# ----> 1 t
#
# NameError: name 't' is not defined

# %%
r.table("company_domain_research").delete().run(conn)
# Out:
# {u'deleted': 1106,
#  u'errors': 0,
#  u'inserted': 0,
#  u'replaced': 0,
#  u'skipped': 0,
#  u'unchanged': 0}

# %%
import requests

# %%
rr = requests.get("http://localhost:7000/")

# %%
r.table("triggers").index_create("domain").run(conn)
# Out:
# {u'created': 1}

# %%
url ='https://dc80f4192b73cca928f4e7c284b46573:@company-stream.clearbit.com/v1/companies/domain/stripe.com'

# %%
r.table("triggers").get({"domain":})

# %%
requests.get(url).json()
# Out:
# {u'angellist': {u'blogUrl': u'https://stripe.com/blog',
#   u'description': None,
#   u'followers': 1170,
#   u'handle': u'stripe',
#   u'id': 37232},
#  u'category': {u'industry': u'Software',
#   u'industryGroup': u'Software & Services',
#   u'sector': u'Information Technology',
#   u'subIndustry': u'Application Software'},
#  u'crunchbase': {u'handle': u'stripe'},
#  u'description': u'A set of unified APIs and tools that instantly enable businesses to accept and manage online payments.',
#  u'domain': u'stripe.com',
#  u'domainAliases': [],
#  u'emailProvider': False,
#  u'facebook': {u'handle': u'stripepayments', u'likes': None},
#  u'foundedDate': u'2011-09-01',
#  u'geo': {u'city': u'San Francisco',
#   u'country': u'United States',
#   u'countryCode': u'US',
#   u'lat': 37.76238499999999,
#   u'lng': -122.414601,
#   u'postalCode': u'94110',
#   u'state': u'California',
#   u'stateCode': u'CA',
#   u'streetName': u'18th Street',
#   u'streetNumber': u'3180',
# ...

# %%
data = r.table("triggers").filter(lambda trigger: trigger.has_fields("domain"))
#data = data.order_by("created_at")
data = data.order_by(r.desc("timestamp"))

# %%
pd.DataFrame(data.run(conn))
# Out:
#      company_domain_research_completed company_domain_research_result  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# 5                                  NaN                            NaN
# 6                                  NaN                            NaN
# 7                                  NaN                            NaN
# 8                                  NaN                            NaN
# 9                                  NaN                            NaN
# 10    2015-11-05 20:07:51.968000+00:00                          found
# 11                                 NaN                            NaN
# ...

# %%
q = pd.DataFrame(requests.get("http://localhost:7000/triggers/0").json())

# %%
q
# Out:
#    company_domain_research_result  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                           found
# 5                       not found
# 6                             NaN
# 7                           found
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                          found
# 15                            NaN
# 16                            NaN
# 17                            NaN
# 18                            NaN
# 19                            NaN
# 20                            NaN
# 21                            NaN
# 22                            NaN
# 23                            NaN
# 24                            NaN
# 25                            NaN
# ...

# %%
from scraping.job_board.zip_recruiter import ZipRecruiter

# %%
import arrow
import pandas as pd
import rethinkdb as r

# %%
conn = r.connect(db="triggeriq", auth_key="PPxYaDVvVmDhXccvM2qdGzFhyIdwcLpYSuyGIbTFD5c")

# %%
t = pd.DataFrame(list(r.table("triggers").run(conn)))

# %%
e = pd.DataFrame(list(r.table("company_employees").run(conn)))
print e.company_id.value_counts()
print e.profile_id.value_counts()
# Out:
# datto,inc._ecb37662-59d9-4170-94ae-142f02907ee6                     69
# datto,inc._a5d84612-3088-483d-b690-5999baa0977e                     45
# j.j.keller&associates,inc_ecb37662-59d9-4170-94ae-142f02907ee6      34
# j.j.keller&associates,inc_a5d84612-3088-483d-b690-5999baa0977e      33
# probuild_a5d84612-3088-483d-b690-5999baa0977e                       23
# vaco_515c1422-3e08-4c07-83f8-fb99883440f8                           22
# manulife_ecb37662-59d9-4170-94ae-142f02907ee6                       20
# ecriinstitute_ecb37662-59d9-4170-94ae-142f02907ee6                  19
# accionlabs_515c1422-3e08-4c07-83f8-fb99883440f8                     16
# gulfeaglesupply_ecb37662-59d9-4170-94ae-142f02907ee6                15
# biscoindustries_ecb37662-59d9-4170-94ae-142f02907ee6                15
# manulife_a5d84612-3088-483d-b690-5999baa0977e                       10
# gulfeaglesupply_a5d84612-3088-483d-b690-5999baa0977e                 7
# ...

# %%
et = t[~t.company_key.isin(e.company_id.unique())]

# %%
et[et.employee_search_completed.isnull()].shape
# Out:
# (3626, 15)

# %%
# signup

# login

# free trial
# - 

# endpoint authorization / authentication
# - 
# - 

# invalidate user session tokens
# - 

# stripe upgrade downgrade
# - 

# intercom
# -

# %%
import json

# %%
conn = r.connect(db="triggeriq")

# %%
pd.DataFrame(list(r.table("prospect_profiles").run(conn))).to_dict("r")
# Out:
# [{u'id': u'c2a9d9fb-a1ff-486d-aef5-62abcb111b59',
#   u'name': u'inside sales',
#   u'profiles': [{u'className': u'HiringProfile',
#     u'locales': [],
#     u'roles': [u'inside sales']}],
#   u'titles': [u'sales']},
#  {u'id': u'523e96d0-a484-43d9-8f9c-258e43ad1048',
#   u'name': u'First',
#   u'profiles': [{u'className': u'HiringProfile',
#     u'locales': [],
#     u'roles': [u'inside sales']}],
#   u'titles': nan},
#  {u'id': u'27ed74bd-6c61-4611-9fbd-2f262a7b6920',
#   u'name': u'First',
#   u'profiles': [{u'className': u'HiringProfile',
#     u'locales': [],
#     u'roles': [u'ios developer']}],
#   u'titles': nan}]

# %%
r.table_create("press_events",primary_key="link").run(conn)

# %%
import rethinkdb as r
import pandas as pd
import arrow

# %%
conn = r.connect(db="triggeriq", auth_key="PPxYaDVvVmDhXccvM2qdGzFhyIdwcLpYSuyGIbTFD5c")

# %%
t = pd.DataFrame(list(r.table("triggers").run(conn)))

# %%
e = pd.DataFrame(list(r.table("company_employees").run(conn)))

# %%
arrow.now().time
# Out:
#                                               company_id  \
# 0      tempursealyinternational_a5d84612-3088-483d-b6...
# 1      kaiserpermanente_515c1422-3e08-4c07-83f8-fb998...
# 2      innovativesolutionadvisors/stadiumpeople_515c1...
# 3      siriuscomputersolutions_ecb37662-59d9-4170-94a...
# 4           corbion_ecb37662-59d9-4170-94ae-142f02907ee6
# 5      lennoxinternationalcorporation_ecb37662-59d9-4...
# 6                                                    NaN
# 7      communitysafetynet_a5d84612-3088-483d-b690-599...
# 8                                                    NaN
# 9                                                    NaN
# 10     donaldsoncompany,inc._a5d84612-3088-483d-b690-...
# 11                                                   NaN
# 12     donaldsoncompany,inc._ecb37662-59d9-4170-94ae-...
# 13     tempursealyinternational_a5d84612-3088-483d-b6...
# 14                                                   NaN
# ...

# %%
conn = r.connect(db="triggeriq")

# %%
r.table()

# %%
ps = pd.DataFrame(list(r.table("press_subjects").run(conn)))
pi = pd.DataFrame(list(r.table("press_industries").run(conn)))
r.table("press_industries").insert(pi[["industry"]].to_dict("r")).run(conn)
r.table("press_subjects").insert(ps[["subject"]].to_dict("r")).run(conn)

# %%
pe = pd.DataFrame(list(r.table("press_events").run(conn)))

# %%
pe.link.value_counts()
# Out:
# http://www.marketwired.com/mw/release.do?id=2064782&sourceType=3                                                        1
# http://www.marketwired.com/mw/release.do?id=2065294&sourceType=3                                                        1
# http://feeds.businesswire.com/click.phdo?i=1d7de0eff66aee54c3d80265af3a6184                                             1
# http://www.prweb.com/releases/2015/10/prweb13036659.htm                                                                 1
# http://feeds.businesswire.com/click.phdo?i=9b4a7790da7d46ab4c29b2f264a8f42c                                             1
# http://www.marketwired.com/mw/release.do?id=2066523&sourceType=3                                                        1
# http://www.marketwired.com/mw/release.do?id=2066566&sourceType=3                                                        1
# http://www.prweb.com/releases/2015/10/prweb13028034.htm                                                                 1
# ...

# %%
r.table("db").run(conn)
# Out:
# ---------------------------------------------------------------------------
# ReqlRuntimeError                          Traceback (most recent call last)
# <ipython-input-139-671f85188e97> in <module>()
# ----> 1 r.table("db").run(conn)
#
# /Users/robin/anaconda/lib/python2.7/site-packages/rethinkdb/ast.pyc in run(self, c, **global_optargs)
#     116                         " a connection to run on.")
#     117
# --> 118         return c._start(self, **global_optargs)
#     119
#     120     def __str__(self):
#
# /Users/robin/anaconda/lib/python2.7/site-packages/rethinkdb/net.pyc in _start(self, term, **global_optargs)
#     578             global_optargs['db'] = DB(global_optargs.get('db', self.db))
#     579         q = Query(pQuery.START, self._new_token(), term, global_optargs)
# --> 580         return self._instance.run_query(q, global_optargs.get('noreply', False))
#     581
#     582     def _continue(self, cursor):
#
# ...

# %%
pd.DataFrame(list(r.db("rethinkdb").table("stats").run(conn)))
# Out:
#             db                                                 id  \
# 0          NaN                                          [cluster]
# 1          NaN     [server, 2117eb8c-6e24-4b4a-9e6c-6bf18d1fb632]
# 2     socialiq      [table, 081e5ba3-b1c8-4ca9-828e-39e21261311a]
# 3    triggeriq      [table, 0cdaf409-7059-45e1-85d8-056e2c990ff7]
# 4     socialiq      [table, 21e1fff7-e395-47e3-a04a-50bde874bfd8]
# 5    triggeriq      [table, 3af2c29a-f56f-4c4e-bb6a-d87008197e36]
# 6     socialiq      [table, 455d3adf-f9c7-483a-88fc-94f3b2df1654]
# 7    triggeriq      [table, 48820722-0406-4b74-8049-9c4b1ae45acf]
# 8     socialiq      [table, 4b8ef631-52a1-455b-b81a-2d7307db3b93]
# 9    triggeriq      [table, 4ca2738e-000f-480f-b1a3-288f50b25d91]
# 10   triggeriq      [table, 4dda02d4-9b9a-4674-96fa-c2490f7c85b8]
# 11    socialiq      [table, 58d97c1f-5c7a-490c-aa5b-828c15d34f1c]
# 12   triggeriq      [table, 5c8db4e3-1a3e-4cc9-a490-82ab10c3b4c7]
# ...

# %%
def _parse_response(self, response):
    html = response.body
    ep = json.loads(html)
    print ep.keys()
    if "pattern" in ep.keys():
        del ep["emails"]
        if ep["pattern"] == "none":
            ep["stache"] = None
            ep["pattern"] = None
        else:
            data = {"first":"{{first}}","last":"{{last}}"}
            data["f"] = "{{first_initial}}"
            data["l"] = "{{last_initial}}"
            ep["stache"] = ep["pattern"].format(**data)
            ep["stache"] = ep["stache"]+"@{{domain}}"
    else:
        ep = None
    data = {"email_pattern":ep, "emailhunter_search_completed": r.now()}
    return data

# %%
import rethinkdb as r
import requests

# %%
domain = "guidespark.com"
api_key = "493b454750ba86fd4bd6c2114238ef43696fce14"
url = "http://api.emailhunter.co/v1/search?domain={0}&api_key={1}"

# %%
html = requests.get(url.format(domain, api_key)).text

# %%
ep = json.loads(html)
#print ep.keys()
if "pattern" in ep.keys():
    del ep["emails"]
    if ep["pattern"] == "none":
        ep["stache"] = None
        ep["pattern"] = None
    else:
        data = {"first":"{{first}}","last":"{{last}}"}
        data["f"] = "{{first_initial}}"
        data["l"] = "{{last_initial}}"
        ep["stache"] = ep["pattern"].format(**data)
        ep["stache"] = ep["stache"]+"@{{domain}}"
else:
    ep = None
data = {"email_pattern":ep, "emailhunter_search_completed": r.now()}
print data
# Out:
# {'emailhunter_search_completed': <RqlQuery instance: r.now() >, 'email_pattern': {u'status': u'success', u'domain': u'guidespark.com', u'pattern': u'{first}_{last}', u'results': 16, u'webmail': False, 'stache': u'{{first}}_{{last}}@{{domain}}', u'offset': 0}}
