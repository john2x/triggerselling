# %%
import arrow

# %%
from rq import Queue
from worker import conn as _conn
q = Queue("low", connection=_conn)
default_q = Queue("default", connection=_conn)
high_q = Queue("high", connection=_conn)

# %%
j = q.jobs

# %%
j2 = q.jobs

# %%
len(j)
# Out:
# 55607

# %%
arrow.utcnow().timestamp
# Out:
# 1445659892

# %%
=
# Out:
# 55607

# %%
# Out:
# 57129

# %%
j = q.jobs
j2 = q.jobs

ids = [i.id for i in j]
_ids = [i.id for i in j2]
    
number_of_new_jobs_added = len(_ids) - _ids.index(ids[-1])
number_of_jobs_finished = ids.index(_ids[0])
# Out:
# 1523

# %%
old, new = j, j2
# run every second

# %%
# read timestamp, old from pickle
new = q.jobs
timestamp = arrow.utcnow().timestamp

ids = [i.id for i in old]
_ids = [i.id for i in new]

number_of_new_jobs_added = len(_ids) - _ids.index(ids[-1])
number_of_jobs_finished = ids.index(_ids[0])

# store timestamp, new in pickle

# %%
from simmetrica import Simmetrica

# %%
from simmetrica import Simmetrica
simmetrica = Simmetrica()
simmetrica.push('add-cart-action')
# Out:
# [4L, 4L, 3L, 4L, 3L, 4L, 4L, 4L]

# %%
start = simmetrica.get_current_timestamp() - 600
end = simmetrica.get_current_timestamp()
results = simmetrica.query('add-cart-action', start, end, 'min')
for time, val in results:
    print time, val
# Out:
# 1445661120 0
# 1445661180 0
# 1445661240 0
# 1445661300 0
# 1445661360 0
# 1445661420 0
# 1445661480 0
# 1445661540 1
# 1445661600 0
# 1445661660 3

# %%
j[0]
# Out:
# Job(u'0e0baf04-d090-4e22-9647-840ea4e0eae9', enqueued_at=datetime.datetime(2015, 10, 23, 19, 24, 21))

# %%
import datetime

# %%
arrow.get(datetime.datetime(2015, 10, 23, 19, 24, 21)).humanize()
# Out:
# u'9 hours ago'

# %%
import time
start_time = time.time()
main()
print("--- %s seconds ---" % (time.time() - start_time))

# %%
c.sort("createdAt",ascending=False)
# Out:
# /Users/robin/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     bing_results                                       company_name  \
# 937       [8, 4]                                U.S. Tech Solutions
# 608       [8, 4]                                    Tristaff Search
# 814      [10, 4]                                        Triad Group
# 659       [7, 4]                                     Walmart Canada
# 554       [8, 4]                                        Plantronics
# 758      [10, 4]                       Paul Hope - State Farm Agent
# 100       [8, 4]                                       Saxon Global
# 83        [6, 4]                                            Webroot
# 974       [8, 4]                                  Ascendo Resources
# 426       [3, 4]                                            Zigatta
# 636       [8, 4]                                    Town Pump, Inc.
# 822       [6, 4]                                    Yusen Logistics
# 916       [8, 4]                                     iTech US, Inc.
# 874      [10, 4]                             G & S Technology Group
# 530       [8, 4]                                       M9 Solutions
# 579      [10, 4]                                          X-pertize
# 125       [8, 4]                             Westshore Technologies
# 243       [8, 4]                      Strategic Recruiting Services
# 43       [10, 4]                                         Visionstar
# 620       [8, 4]                                     Tts Technology
# 439       [8, 4]                              Twin Tier Hospitality
# 682       [8, 4]                                            Truefit
# 257       [8, 4]                                   Nextgen Tech Inc
# 698       [8, 4]                                         State Farm
# 403      [10, 4]                           Tekmark Global Solutions
# 570       [8, 4]                          Technology Resource Group
# 402       [8, 4]                                Matching Principles
# 41        [8, 4]                               T-Mobile / GP Mobile
# 517       [8, 4]                              Smartdoc Technologies
# 685       [8, 4]                                 Skyrocket Ventures
# ..           ...                                                ...
# 903          NaN                  Harrison Reed Computer Consulting
# 900          NaN                  Harrison Reed Computer Consulting
# 835          NaN                       Gypsum Management and Supply
# 619          NaN                                  Gunder Associates
# 103          NaN                                  Gorman Recruiting
# 46           NaN                                Generational Equity
# 748          NaN                                    Gander Mountain
# 628          NaN                                   Gallop Resources
# 428          NaN                                Futuretech Staffing
# 590          NaN                                         Fusion HCR
# 537          NaN                                  FGP International
# 736          NaN                                     ESG Consulting
# 31           NaN                                     Dynamic Signal
# 615          NaN                                        DS Services
# 469          NaN                                         Defy Media
# 323          NaN                                         Debhunters
# 436          NaN                        Cypress Employment Services
# 832          NaN                                        Cybercoders
# 977          NaN                                                Ctg
# 863          NaN                                      Crg Workforce
# 313          NaN  Construction Material, Supplies, and Services ...
# 447          NaN                       Clearbridge Technology Group
# 952          NaN                                  Cingular Staffing
# 858          NaN                             Chameleon Technologies
# 212          NaN                                   Cengage Learning
# 22           NaN                                            Celedon
# 783          NaN                                 Career Transitions
# 136          NaN                             Canon Recruiting Group
# 96           NaN                            Business One Consulting
# 187          NaN                          Building Products Company
#
#       createdAt duckduckgo_results google_results  \
# 937  1445825408             [0, 2]       [100, 6]
# 608  1445825408             [0, 2]        [97, 6]
# 814  1445825404             [0, 2]       [100, 6]
# 659  1445825397             [0, 2]        [97, 6]
# 554  1445825394             [0, 2]        [97, 6]
# 758  1445825394             [0, 2]       [100, 6]
# 100  1445825392             [0, 2]       [100, 6]
# 83   1445825386             [0, 2]        [97, 6]
# 974  1445825377             [0, 2]        [99, 6]
# 426  1445825374             [0, 2]        [99, 6]
# 636  1445825373             [0, 2]        [97, 6]
# 822  1445825373             [0, 2]        [97, 6]
# 916  1445825372             [0, 2]         [0, 2]
# 874  1445825372             [0, 2]         [0, 2]
# 530  1445825372             [0, 2]         [0, 2]
# 579  1445825369             [0, 2]       [100, 6]
# 125  1445825369             [0, 2]        [97, 6]
# 243  1445825365             [0, 2]        [97, 6]
# 43   1445825361             [0, 2]       [100, 6]
# 620  1445825359             [0, 2]       [100, 6]
# 439  1445825359             [0, 2]        [97, 6]
# 682  1445825359             [0, 2]       [100, 6]
# 257  1445825357             [0, 2]       [100, 6]
# 698  1445825356             [0, 2]        [97, 6]
# 403  1445825354             [0, 2]        [97, 6]
# 570  1445825353             [0, 2]       [100, 6]
# 402  1445825352             [0, 2]       [100, 6]
# 41   1445825352             [0, 2]       [100, 6]
# 517  1445825351             [0, 2]        [97, 6]
# 685  1445825349             [0, 2]       [100, 6]
# ..          ...                ...            ...
# 903  1445820889                NaN            NaN
# 900  1445820813                NaN            NaN
# 835  1445820792                NaN            NaN
# 619  1445820753                NaN            NaN
# 103  1445820718                NaN            NaN
# 46   1445820697                NaN            NaN
# 748  1445820656                NaN            NaN
# 628  1445820624                NaN            NaN
# 428  1445820611                NaN            NaN
# 590  1445820596                NaN            NaN
# 537  1445820572                NaN            NaN
# 736  1445820549                NaN            NaN
# 31   1445820414                NaN            NaN
# 615  1445820301                NaN            NaN
# 469  1445820261                NaN            NaN
# 323  1445820243                NaN            NaN
# 436  1445820230                NaN            NaN
# 832  1445820187                NaN            NaN
# 977  1445820168                NaN            NaN
# 863  1445820121                NaN            NaN
# 313  1445820094                NaN            NaN
# 447  1445820075                NaN            NaN
# 952  1445820031                NaN            NaN
# 858  1445820019                NaN            NaN
# 212  1445819996                NaN            NaN
# 22   1445819956                NaN            NaN
# 783  1445819935                NaN            NaN
# 136  1445819924                NaN            NaN
# 96   1445819904                NaN            NaN
# 187  1445819857                NaN            NaN
#
#                                        id  \
# 937  fa9a1ded-6574-4fba-bda6-e785e843f714
# 608  d2ec0304-9170-4d25-b509-22800134082c
# 814  e0a9e375-ec56-4d82-88ff-f34df64dd47e
# 659  701a3f59-9995-4558-a0b8-401e4e506335
# 554  72661410-33f2-4f93-b295-c89472186135
# 758  721d604e-e87b-4901-9d0b-7f034fc78d16
# 100  23347ed8-d41c-4b25-bf77-49476413c97f
# 83   22a1e66a-dd61-4fe0-a6fa-40db37bd6387
# 974  ff5e4a2e-142b-46d2-9268-9cb94c170147
# 426  e75a3bae-ee8a-41d7-aaac-f73f089e21fb
# 636  487f9f6c-b979-442c-9d72-ce8f82e81a24
# 822  34161a72-94d8-4bae-91aa-a63f275582d1
# 916  d7b9660d-9f6b-4f8a-bd94-7dbdd7f543a7
# 874  7977ddcc-e2e3-4f8c-87b2-455e7877189b
# 530  5619edd8-e686-4918-8efd-7cb3d8c4b0a2
# 579  a44f26d4-0c7b-495a-b095-dd9f59e83963
# 125  1a61b678-9caa-455c-b3a9-1c9882601149
# 243  b42f86c0-f3a7-4855-9115-8cc4366c9126
# 43   25fe6e82-80a9-4d5a-8e31-ad1365552c0d
# 620  e0412cfe-eb46-4f92-9311-8e2a9043a241
# 439  4cedea7e-0708-4087-8b15-92053ae2367f
# 682  9ff9df48-c654-4552-8514-bcec36de1202
# 257  d5d79742-3ca4-4640-aa6f-94e7823fbc7e
# 698  bcdeba86-e957-45eb-9365-5c5354744268
# 403  ad9080dd-ae07-4bd6-95bb-7dbcd2eeed7e
# 570  9478a0b4-51ad-4885-b2d5-074e07e85673
# 402  ad2a3039-c8c0-46c6-b9e8-b92b13bc16db
# 41   24270f72-db24-48db-9615-3550d1df3600
# 517  435ee839-9fa8-4cc2-b4da-f3b352552007
# 685  a90036c1-fe0d-4b4f-8bbc-294460f92ad1
# ..                                    ...
# 903  c0c29854-25d2-4e30-9b56-bf8d50e7cdd5
# 900  b9364bef-76d7-4a7e-844e-8fa2f721fecb
# 835  455d4e58-b92c-466e-b483-c58b13df101b
# 619  de23bacd-1d97-41b5-86bf-7ea8914412eb
# 103  2997cfec-d508-44e7-a88b-d9595cdb9393
# 46   058c7200-06a6-4cbb-ba75-7344955b7438
# 748  5ee4c3ec-84b4-4b55-8cc3-4328ac35a595
# 628  3e4c0875-2cbc-4a7a-ac59-e3437f748b4b
# 428  ea8dc928-4184-41b8-9537-d896c1eb22f3
# 590  b33747c5-035a-479c-b4c9-ac80659c2ada
# 537  5f945603-ab5a-4989-9821-05ddfa893b7c
# 736  4859ffef-8e57-45ee-bb02-063371785422
# 31   11722e08-9a53-401a-b078-ec2c87acc29f
# 615  da61f04e-05e2-4410-93fe-bc14e564ee1a
# 469  9088d9ab-b180-4a59-9b53-593416e44a10
# 323  c58f4ffa-f262-4bee-8786-de8330ee7a94
# 436  47c7ae5d-f501-44d4-9f95-61a9d375ebe6
# 832  4300f7c4-4537-4390-860c-ae3856bf09cf
# 977  f0849c2f-908f-4ec5-811c-5e0dcb83a8a2
# 863  69077063-6488-4c3d-b6c7-9d1e64efc1ec
# 313  adfed0c0-3a4d-4b35-a198-96f679898ebf
# 447  653beecb-c251-487b-87d9-d5a57b9649d1
# 952  fcdf0a8c-089a-416f-8acd-4edfd749071f
# 858  6269475e-382d-44a8-9f50-7329662d1a28
# 212  6c649fa2-d6af-422c-b9e8-9d034ed68c94
# 22   031118b2-c0d9-417f-8d17-36b3303153d3
# 783  a2ab505d-c519-44f1-90ce-aa2665806e06
# 136  2bbdefba-b768-491f-b457-a0cfad584f98
# 96   14fb3724-5175-440f-af98-c0fdd2ede28f
# 187  3bf4e1fc-145a-469c-9836-334216fc9dc9
#
#                                              long_list  \
# 937  [{u'confidence': 162.5, u'new_score': 13, u'do...
# 608  [{u'confidence': 212.5, u'new_score': 17, u'do...
# 814  [{u'confidence': 187.5, u'new_score': 15, u'do...
# 659  [{u'confidence': 200, u'new_score': 16, u'doma...
# 554  [{u'confidence': 225, u'new_score': 18, u'doma...
# 758  [{u'confidence': 225, u'new_score': 18, u'doma...
# 100  [{u'confidence': 175, u'new_score': 14, u'doma...
# 83   [{u'confidence': 212.5, u'new_score': 17, u'do...
# 974  [{u'confidence': 187.5, u'new_score': 15, u'do...
# 426  [{u'confidence': 212.5, u'new_score': 17, u'do...
# 636  [{u'confidence': 200, u'new_score': 16, u'doma...
# 822  [{u'confidence': 212.5, u'new_score': 17, u'do...
# 916  [{u'confidence': 162.5, u'new_score': 13, u'do...
# 874  [{u'confidence': 187.5, u'new_score': 15, u'do...
# 530  [{u'confidence': 162.5, u'new_score': 13, u'do...
# 579  [{u'confidence': 200, u'new_score': 16, u'doma...
# 125  [{u'confidence': 212.5, u'new_score': 17, u'do...
# 243  [{u'confidence': 200, u'new_score': 16, u'doma...
# 43   [{u'confidence': 187.5, u'new_score': 15, u'do...
# 620  [{u'confidence': 225, u'new_score': 18, u'doma...
# 439  [{u'confidence': 187.5, u'new_score': 15, u'do...
# 682  [{u'confidence': 225, u'new_score': 18, u'doma...
# 257  [{u'confidence': 212.5, u'new_score': 17, u'do...
# 698  [{u'confidence': 200, u'new_score': 16, u'doma...
# 403  [{u'confidence': 212.5, u'new_score': 17, u'do...
# 570  [{u'confidence': 187.5, u'new_score': 15, u'do...
# 402  [{u'confidence': 200, u'new_score': 16, u'doma...
# 41   [{u'confidence': 200, u'new_score': 16, u'doma...
# 517  [{u'confidence': 212.5, u'new_score': 17, u'do...
# 685  [{u'confidence': 187.5, u'new_score': 15, u'do...
# ..                                                 ...
# 903  [{u'confidence': 212.5, u'new_score': 17, u'do...
# 900  [{u'confidence': 175, u'new_score': 14, u'doma...
# 835  [{u'confidence': 200, u'new_score': 16, u'doma...
# 619  [{u'confidence': 200, u'new_score': 16, u'doma...
# 103  [{u'confidence': 212.5, u'new_score': 17, u'do...
# 46   [{u'confidence': 200, u'new_score': 16, u'doma...
# 748  [{u'confidence': 225, u'new_score': 18, u'doma...
# 628  [{u'confidence': 150, u'new_score': 12, u'doma...
# 428  [{u'confidence': 200, u'new_score': 16, u'doma...
# 590  [{u'confidence': 212.5, u'new_score': 17, u'do...
# 537  [{u'confidence': 162.5, u'new_score': 13, u'do...
# 736  [{u'confidence': 175, u'new_score': 14, u'doma...
# 31   [{u'confidence': 225, u'new_score': 18, u'doma...
# 615  [{u'confidence': 175, u'new_score': 14, u'doma...
# 469  [{u'confidence': 200, u'new_score': 16, u'doma...
# 323  [{u'confidence': 200, u'new_score': 16, u'doma...
# 436  [{u'confidence': 125, u'new_score': 10, u'doma...
# 832  [{u'confidence': 150, u'new_score': 12, u'doma...
# 977  [{u'confidence': 225, u'new_score': 18, u'doma...
# 863  [{u'confidence': 187.5, u'new_score': 15, u'do...
# 313  [{u'confidence': 175, u'new_score': 14, u'doma...
# 447  [{u'confidence': 187.5, u'new_score': 15, u'do...
# 952  [{u'confidence': 175, u'new_score': 14, u'doma...
# 858  [{u'confidence': 200, u'new_score': 16, u'doma...
# 212  [{u'confidence': 187.5, u'new_score': 15, u'do...
# 22   [{u'confidence': 162.5, u'new_score': 13, u'do...
# 783  [{u'confidence': 212.5, u'new_score': 17, u'do...
# 136  [{u'confidence': 187.5, u'new_score': 15, u'do...
# 96   [{u'confidence': 200, u'new_score': 16, u'doma...
# 187  [{u'confidence': 225, u'new_score': 18, u'doma...
#
#                         selected  \
# 937          ustechsolutions.com
# 608                 tristaff.com
# 814            thetriadgroup.com
# 659                   walmart.ca
# 554              plantronics.com
# 758                statefarm.com
# 100                 facebook.com
# 83                   webroot.com
# 974                  ascendo.com
# 426                     dice.com
# 636                 townpump.com
# 822          yusen-logistics.com
# 916                  itechus.com
# 874                  nngroup.com
# 530              m9solutions.com
# 579                x-pertize.com
# 125                  monster.com
# 243      strategicrecruiting.net
# 43                visionstar.com
# 620              ttswireless.com
# 439          twintiercareers.com
# 682                  truefit.com
# 257           nextgentechinc.com
# 698                statefarm.com
# 403               tekmarkinc.com
# 570            tech-resource.com
# 402          accountingtools.com
# 41                  t-mobile.com
# 517             smartdoctech.com
# 685        skyrocketventures.com
# ..                           ...
# 903                 linkedin.com
# 900                   indeed.com
# 835          corporationwiki.com
# 619                gunderllc.com
# 103         gormanrecruiting.com
# 46               genequityco.com
# 748           gandermountain.com
# 628  nationalautismresources.com
# 428                   indeed.com
# 590                fusionhcr.com
# 537                  monster.com
# 736                 linkedin.com
# 31             dynamicsignal.com
# 615            dsservicesinc.com
# 469                defymedia.com
# 323                 linkedin.com
# 436              yellowpages.com
# 832              cybercoders.com
# 977                      ctg.com
# 863             crgworkforce.com
# 313  cmcconstructionservices.com
# 447            careerbuilder.com
# 952         cingularstaffing.com
# 858            chameleontech.net
# 212             cengagebrain.com
# 22               celadonnapa.com
# 783        careertransitions.com
# 136          canonrecruiting.com
# 96     businessoneconsulting.com
# 187  buildingproductscompany.com
#
#                                             short_list yandex_results
# 937  [{u'confidence': 162.5, u'new_score': 13, u'do...         [0, 2]
# 608  [{u'confidence': 212.5, u'new_score': 17, u'do...         [0, 2]
# 814  [{u'confidence': 137.5, u'new_score': 11, u'do...         [0, 2]
# 659  [{u'confidence': 200, u'new_score': 16, u'doma...         [0, 2]
# 554  [{u'confidence': 225, u'new_score': 18, u'doma...         [0, 2]
# 758  [{u'confidence': 225, u'new_score': 18, u'doma...         [0, 2]
# 100  [{u'confidence': 150, u'new_score': 12, u'doma...         [0, 2]
# 83   [{u'confidence': 212.5, u'new_score': 17, u'do...         [0, 2]
# 974  [{u'confidence': 175, u'new_score': 14, u'doma...         [0, 2]
# 426  [{u'confidence': 162.5, u'new_score': 13, u'do...         [0, 2]
# 636  [{u'confidence': 150, u'new_score': 12, u'doma...         [0, 2]
# 822  [{u'confidence': 212.5, u'new_score': 17, u'do...         [0, 2]
# 916  [{u'confidence': 137.5, u'new_score': 11, u'do...         [0, 2]
# 874  [{u'confidence': 187.5, u'new_score': 15, u'do...         [0, 2]
# 530  [{u'confidence': 137.5, u'new_score': 11, u'do...         [0, 2]
# 579  [{u'confidence': 200, u'new_score': 16, u'doma...         [0, 2]
# 125  [{u'confidence': 112.5, u'new_score': 9, u'dom...         [0, 2]
# 243  [{u'confidence': 200, u'new_score': 16, u'doma...         [0, 2]
# 43   [{u'confidence': 187.5, u'new_score': 15, u'do...         [0, 2]
# 620  [{u'confidence': 112.5, u'new_score': 9, u'dom...         [0, 2]
# 439  [{u'confidence': 187.5, u'new_score': 15, u'do...         [0, 2]
# 682  [{u'confidence': 225, u'new_score': 18, u'doma...         [0, 2]
# 257  [{u'confidence': 212.5, u'new_score': 17, u'do...         [0, 2]
# 698  [{u'confidence': 187.5, u'new_score': 15, u'do...         [0, 2]
# 403  [{u'confidence': 212.5, u'new_score': 17, u'do...         [0, 2]
# 570  [{u'confidence': 150, u'new_score': 12, u'doma...         [0, 2]
# 402  [{u'confidence': 200, u'new_score': 16, u'doma...         [0, 2]
# 41   [{u'confidence': 175, u'new_score': 14, u'doma...         [0, 2]
# 517  [{u'confidence': 137.5, u'new_score': 11, u'do...         [0, 2]
# 685  [{u'confidence': 162.5, u'new_score': 13, u'do...         [0, 2]
# ..                                                 ...            ...
# 903  [{u'confidence': 212.5, u'new_score': 17, u'do...            NaN
# 900  [{u'confidence': 175, u'new_score': 14, u'doma...            NaN
# 835  [{u'confidence': 100, u'new_score': 8, u'domai...            NaN
# 619  [{u'confidence': 175, u'new_score': 14, u'doma...            NaN
# 103  [{u'confidence': 187.5, u'new_score': 15, u'do...            NaN
# 46   [{u'confidence': 200, u'new_score': 16, u'doma...            NaN
# 748  [{u'confidence': 225, u'new_score': 18, u'doma...            NaN
# 628  [{u'confidence': 150, u'new_score': 12, u'doma...            NaN
# 428  [{u'confidence': 137.5, u'new_score': 11, u'do...            NaN
# 590  [{u'confidence': 212.5, u'new_score': 17, u'do...            NaN
# 537  [{u'confidence': 150, u'new_score': 12, u'doma...            NaN
# 736  [{u'confidence': 150, u'new_score': 12, u'doma...            NaN
# 31   [{u'confidence': 225, u'new_score': 18, u'doma...            NaN
# 615  [{u'confidence': 162.5, u'new_score': 13, u'do...            NaN
# 469  [{u'confidence': 187.5, u'new_score': 15, u'do...            NaN
# 323  [{u'confidence': 200, u'new_score': 16, u'doma...            NaN
# 436  [{u'confidence': 100, u'new_score': 8, u'domai...            NaN
# 832  [{u'confidence': 150, u'new_score': 12, u'doma...            NaN
# 977  [{u'confidence': 225, u'new_score': 18, u'doma...            NaN
# 863  [{u'confidence': 187.5, u'new_score': 15, u'do...            NaN
# 313  [{u'confidence': 162.5, u'new_score': 13, u'do...            NaN
# 447  [{u'confidence': 150, u'new_score': 12, u'doma...            NaN
# 952  [{u'confidence': 175, u'new_score': 14, u'doma...            NaN
# 858  [{u'confidence': 200, u'new_score': 16, u'doma...            NaN
# 212  [{u'confidence': 137.5, u'new_score': 11, u'do...            NaN
# 22   [{u'confidence': 112.5, u'new_score': 9, u'dom...            NaN
# 783  [{u'confidence': 175, u'new_score': 14, u'doma...            NaN
# 136  [{u'confidence': 187.5, u'new_score': 15, u'do...            NaN
# 96   [{u'confidence': 200, u'new_score': 16, u'doma...            NaN
# 187  [{u'confidence': 225, u'new_score': 18, u'doma...            NaN
#
# [1019 rows x 10 columns]

# %%
arrow.get(1445824926).humanize()
# Out:
# u'a minute ago'

# %%
c.ix[556].short_list
# Out:
# [{u'confidence': 212.5,
#   u'domain': u'linkedin.com',
#   u'fuzz_score': 27,
#   u'new_score': 17,
#   u'old_score': 1},
#  {u'confidence': 125,
#   u'domain': u'examiner.com',
#   u'fuzz_score': 27,
#   u'new_score': 10,
#   u'old_score': 4},
#  {u'confidence': 112.5,
#   u'domain': u'hr-secrets.com',
#   u'fuzz_score': 26,
#   u'new_score': 9,
#   u'old_score': 0}]

# %%
c.ix[556].long_list
# Out:
# [{u'confidence': 212.5,
#   u'domain': u'linkedin.com',
#   u'new_score': 17,
#   u'old_score': 1},
#  {u'confidence': 125,
#   u'domain': u'examiner.com',
#   u'new_score': 10,
#   u'old_score': 4},
#  {u'confidence': 112.5,
#   u'domain': u'hr-secrets.com',
#   u'new_score': 9,
#   u'old_score': 0},
#  {u'confidence': 100, u'domain': u'co.uk', u'new_score': 8, u'old_score': 1},
#  {u'confidence': 87.5,
#   u'domain': u'dice.com',
#   u'new_score': 7,
#   u'old_score': 2},
#  {u'confidence': 75,
#   u'domain': u'fordharrison.com',
#   u'new_score': 6,
#   u'old_score': 1},
#  {u'confidence': 75,
#   u'domain': u'middlesexcountymagazine.com',
#   u'new_score': 6,
#   u'old_score': 1},
#  {u'confidence': 62.5,
#   u'domain': u'simplyhired.com',
#   u'new_score': 5,
#   u'old_score': 1},
#  {u'confidence': 62.5,
#   u'domain': u'computerhistory.org',
#   u'new_score': 5,
#   u'old_score': 2},
#  {u'confidence': 50,
#   u'domain': u'winsummit.com',
#   u'new_score': 4,
#   u'old_score': 1},
#  {u'confidence': 50,
#   u'domain': u'indeed.com',
#   u'new_score': 4,
#   u'old_score': 2},
#  {u'confidence': 37.5,
#   u'domain': u'partnerconnectevents.com',
#   u'new_score': 3,
#   u'old_score': 1},
#  {u'confidence': 25,
#   u'domain': u'net-temps.com',
#   u'new_score': 2,
#   u'old_score': 3},
#  {u'confidence': 25,
#   u'domain': u'kantrowitz.com',
#   u'new_score': 2,
#   u'old_score': 1},
#  {u'confidence': 12.5,
#   u'domain': u'lead411.com',
#   u'new_score': 1,
#   u'old_score': 4},
#  {u'confidence': 12.5,
#   u'domain': u'jobalot.com',
#   u'new_score': 1,
#   u'old_score': 1},
#  {u'confidence': 0,
#   u'domain': u'monster.com',
#   u'new_score': 0,
#   u'old_score': 4}]
